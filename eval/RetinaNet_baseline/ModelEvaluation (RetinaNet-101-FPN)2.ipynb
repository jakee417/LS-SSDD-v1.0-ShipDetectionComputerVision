# %% [markdown]
# # Resources and credit:
# - SSDD data download: https://github.com/TianwenZhang0825/LS-SSDD-v1.0-OPEN
# - Detectron2 docs: https://detectron2.readthedocs.io/en/latest/index.html
# - Conceptual: https://medium.com/@hirotoschwert/digging-into-detectron-2-part-5-6e220d762f9
# - Conceptual: https://jonathan-hui.medium.com/map-mean-average-precision-for-object-detection-45c121a31173

# %% [markdown]
# # Installation of detectron2 and Imports
# *Standard from Detectron2's docs*

# %% [markdown]
# *Restart after executing this cell*

# %%
# install dependencies: 
# !pip install pyyaml==5.1
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# opencv is pre-installed on colab
exit(0)
# Out:
# Collecting pyyaml==5.1
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 15.7MB/s
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp36-cp36m-linux_x86_64.whl size=44075 sha256=134c52a7f77b449f42d4047865797b2a4378229f2a01750e0f87e36760669496
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.1
# 1.7.0+cu101 True
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %% [markdown]
# *Restart after executing this cell*

# %%
# install detectron2: (Colab has CUDA 10.1 + torch 1.7)
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
import torch
assert torch.__version__.startswith("1.7")
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/index.html
exit(0)  # After installation, you need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/index.html
# Collecting detectron2
#   Downloading https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/detectron2-0.3%2Bcu101-cp36-cp36m-linux_x86_64.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 712kB/s
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from detectron2) (2.0.2)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.6/dist-packages (from detectron2) (4.41.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.6/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from detectron2) (0.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from detectron2) (0.8.7)
# Collecting Pillow>=7.1
#   Downloading https://files.pythonhosted.org/packages/b6/c0/442d9d87e0da00bf856ef6dd4916f84a2d710b5f1a367d42d7f3c4e99a6c/Pillow-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 19.5MB/s
# Collecting yacs>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.6/dist-packages (from detectron2) (1.1.0)
# Collecting fvcore>=0.1.2
#   Downloading https://files.pythonhosted.org/packages/13/f5/a9cae20e1eac1f28d54a617d21c81d93d826bc4654ebd7a241004df3ef0e/fvcore-0.1.3.post20210219.tar.gz (41kB)
#      |████████████████████████████████| 51kB 9.5MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from detectron2) (3.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (from detectron2) (2.4.1)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools>=2.0.2->detectron2) (53.0.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.6/dist-packages (from pycocotools>=2.0.2->detectron2) (0.29.21)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot->detectron2) (2.4.7)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from yacs>=0.1.6->detectron2) (5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fvcore>=0.1.2->detectron2) (1.19.5)
# Collecting iopath>=0.1.2
#   Downloading https://files.pythonhosted.org/packages/f2/c8/1830019bcecf26e76c3fdc36e2a6fa454388a233894dcf6f5eb00a881468/iopath-0.1.3.tar.gz
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2) (0.10.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (0.10.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (0.36.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (3.12.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.25.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2) (1.8.0)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/82/22/e684c9e2e59b561dbe36538852e81849122c666c423448e3a5c99362c228/portalocker-2.2.1-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2020.12.5)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard->detectron2) (3.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2) (3.7.4.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard->detectron2) (0.4.8)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.3.post20210219-cp36-none-any.whl size=52293 sha256=faef29c28c1a10c385acd500453fc6cc197f5cfeea27703471dc024ca50c27b0
#   Stored in directory: /root/.cache/pip/wheels/be/ab/53/0e83eb05a780266f5de2da54a71ca5feb2a3e417007c442e00
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.3-cp36-none-any.whl size=11169 sha256=2c4dbebf309d8957d1807b0697bc2ea4f92b82828fee99206c1fe342946b89a5
#   Stored in directory: /root/.cache/pip/wheels/a9/1d/55/94a55e032409ac7617f9cbb88a0fa2cf4e7208806c29730804
# Successfully built fvcore iopath
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: Pillow, yacs, portalocker, iopath, fvcore, detectron2
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# Successfully installed Pillow-8.1.0 detectron2-0.3+cu101 fvcore-0.1.3.post20210219 iopath-0.1.3 portalocker-2.2.1 yacs-0.1.8

# %%
# !nvidia-smi
# Out:
# Fri Feb 19 20:09:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %% [markdown]
# # Registration of the custom dataset to detectron2

# %%
# Function that retrieves a standard dataset compatible with detectron2
def get_dict(type):
  """ Returns a list[dict] containing information about the dataset """
  import pickle
  root = '/content/drive/MyDrive/SSDD/datasets/' + type + '/'
  with open(root + "standardDict.pkl", "rb") as input_file:
    return pickle.load(input_file)

# %%
# Global paths
datasets = '/content/drive/MyDrive/SSDD/datasets/'

# Mount Google Drive (Import files from Google Drive in Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from detectron2.structures import BoxMode

pre = 'ssdd_'

# Register
for d in ["train", "test", "test_offshore", "test_inshore"]:
    DatasetCatalog.register(pre + d, lambda d=d: get_dict(d))
    MetadataCatalog.get(pre + d).set(thing_classes=["ship"])

# %%
# Instances of metadata
train_metadata = MetadataCatalog.get(pre + 'train')
test_metadata = MetadataCatalog.get(pre + 'test')
test_offshore_metadata = MetadataCatalog.get(pre + 'test_offshore')
test_inshore_metadata = MetadataCatalog.get(pre + 'test_inshore')

# %% [markdown]
# # Model Loading

# %%
# %cd /content/drive/MyDrive/SSDD/
output = '/content/drive/MyDrive/SSDD/'
model_name = "./ModelOutput/retinanet_R_101_FPN_3x_3"  # Replace w/ folder
# Out:
# /content/drive/.shortcut-targets-by-id/1wPXpOTgpvbBJv06iD212UCxoZiCPIgEH/SSDD

# %%
from detectron2.engine import DefaultTrainer
# detectron2.config - https://detectron2.readthedocs.io/en/latest/modules/config.html

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/retinanet_R_101_FPN_3x.yaml"))  # Replace w/ config
cfg.DATASETS.TRAIN = (pre + "train",)
cfg.DATASETS.TEST = ()
cfg.MODEL.RETINANET.NUM_CLASSES = 1  # only has one class (ship)
cfg.OUTPUT_DIR = model_name

cfg.MODEL.RETINANET.SCORE_THRESH_TEST = 0.5  # (default: 0.05)
cfg.MODEL.RETINANET.NMS_THRESH_TEST = 0.5  # (default: 0.5)

#cfg.MODEL.DEVICE = 'cpu'
# Out:
# Loading config /usr/local/lib/python3.6/dist-packages/detectron2/model_zoo/configs/COCO-Detection/../Base-RetinaNet.yaml with yaml.unsafe_load. Your machine may be at risk if the file contains malicious content.

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=True)
# Out:
# [02/19 20:10:43 d2.engine.defaults]: Model:
# RetinaNet(
#   (backbone): FPN(
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelP6P7(
#       (p6): Conv2d(2048, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (p7): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (head): RetinaNetHead(
#     (cls_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (bbox_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (cls_score): Conv2d(256, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bbox_pred): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (anchor_generator): DefaultAnchorGenerator(
#     (cell_anchors): BufferList()
#   )
# )
# [02/19 20:11:21 d2.data.build]: Removed 4877 images with no usable annotations. 1123 images left.
# [02/19 20:11:21 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 3637         |
# |            |              |
# [02/19 20:11:21 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/19 20:11:21 d2.data.build]: Using training sampler TrainingSampler
# [02/19 20:11:21 d2.data.common]: Serializing 1123 elements to byte tensors and concatenating them all ...
# [02/19 20:11:21 d2.data.common]: Serialized dataset takes 0.34 MiB

# %% [markdown]
# # Evaluation using the trained model
#
# To run inference using the trained model on the validation/test dataset, we first create a predictor using the model we just trained.

# %%
# Inference should use the config with parameters that are used in training
# cfg now already contains everything we've set previously. We changed it a little bit for inference:
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth") # Load custom weights
cfg.MODEL.RETINANET.SCORE_THRESH_TEST = 0.5  # (default: 0.05)
cfg.MODEL.RETINANET.NMS_THRESH_TEST = 0.5  # (default: 0.5)

predictor = DefaultPredictor(cfg)

# %% [markdown]
# ## Visualization
#
# We randomly select several samples to visualize the prediction results.

# %%
#from detectron2.utils.visualizer import ColorMode

dataset_dicts = get_dict("test")   # must be "test", "test_offshore", "test_inshore"

# Filter out pics w/o annotations
dataset_dicts_anns = []
for i in dataset_dicts:
  if i['annotations'] != []:
    dataset_dicts_anns.append(i)

# %%
def printImage(ann, metadata, predictor = None, predFlag = False):
  #from detectron2.utils.visualizer import Visualizer

  im = cv2.imread(ann["file_name"])
  v = Visualizer(im[:, :, ::-1], 
                 metadata=metadata, 
                 scale=0.5)
  
  if predFlag:
    outputs = predictor(im)  # format is documented at https://detectron2.readthedocs.io/tutorials/models.html#model-output-format
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  else:
    out = v.draw_dataset_dict(ann)
  
  image = out.get_image()[:, :, ::-1]

  return image

# %%
os.makedirs(model_name + "/predImages_eval", exist_ok=True)  # Make a directory for output images

# %%
from cv2 import hconcat
random.seed(1)
#set.seed(1)

num_samples = 3

for d in random.sample(dataset_dicts_anns, num_samples):
  image1 = printImage(d, test_metadata, predictor, True)  # Prediction
  image2 = printImage(d, test_metadata, False)  # Ground truth
  image3 = hconcat([image1, image2])

  cv2_imshow(image3) # display an image
  cv2.imwrite(model_name + '/predImages_eval/' + str(d["image_id"] + '.jpg'), image3)  # save an image
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FD30C539630>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FD30C5C6EF0>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7FD30C441438>

# %% [markdown]
# # Evaluation using the COCO Evaluator
#
# We can also evaluate its performance using AP metric implemented in COCO API.

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# %%
# test_offshore
evaluator = COCOEvaluator('ssdd_test_offshore', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_offshore')

print(inference_on_dataset(trainer.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# [02/19 20:18:23 d2.evaluation.coco_evaluation]: 'ssdd_test_offshore' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# WARNING [02/19 20:18:23 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/retinanet_R_101_FPN_3x_3/ssdd_test_offshore_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [02/19 20:18:41 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 1495         |
# |            |              |
# [02/19 20:18:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:18:41 d2.data.common]: Serializing 2234 elements to byte tensors and concatenating them all ...
# [02/19 20:18:41 d2.data.common]: Serialized dataset takes 0.41 MiB
# [02/19 20:18:41 d2.evaluation.evaluator]: Start inference on 2234 images
# [02/19 20:18:43 d2.evaluation.evaluator]: Inference done 11/2234. 0.1021 s / img. ETA=0:03:49
# [02/19 20:18:48 d2.evaluation.evaluator]: Inference done 60/2234. 0.1003 s / img. ETA=0:03:44
# [02/19 20:18:53 d2.evaluation.evaluator]: Inference done 109/2234. 0.0999 s / img. ETA=0:03:38
# [02/19 20:18:58 d2.evaluation.evaluator]: Inference done 158/2234. 0.1000 s / img. ETA=0:03:33
# [02/19 20:19:03 d2.evaluation.evaluator]: Inference done 207/2234. 0.1003 s / img. ETA=0:03:28
# [02/19 20:19:08 d2.evaluation.evaluator]: Inference done 251/2234. 0.1004 s / img. ETA=0:03:28
# [02/19 20:19:14 d2.evaluation.evaluator]: Inference done 300/2234. 0.1006 s / img. ETA=0:03:22
# [02/19 20:19:19 d2.evaluation.evaluator]: Inference done 348/2234. 0.1008 s / img. ETA=0:03:17
# [02/19 20:19:24 d2.evaluation.evaluator]: Inference done 396/2234. 0.1009 s / img. ETA=0:03:12
# [02/19 20:19:29 d2.evaluation.evaluator]: Inference done 444/2234. 0.1011 s / img. ETA=0:03:07
# [02/19 20:19:34 d2.evaluation.evaluator]: Inference done 492/2234. 0.1012 s / img. ETA=0:03:02
# [02/19 20:19:39 d2.evaluation.evaluator]: Inference done 540/2234. 0.1013 s / img. ETA=0:02:57
# [02/19 20:19:44 d2.evaluation.evaluator]: Inference done 588/2234. 0.1015 s / img. ETA=0:02:52
# [02/19 20:19:49 d2.evaluation.evaluator]: Inference done 636/2234. 0.1016 s / img. ETA=0:02:47
# [02/19 20:19:58 d2.evaluation.evaluator]: Inference done 668/2234. 0.1017 s / img. ETA=0:02:57
# [02/19 20:20:03 d2.evaluation.evaluator]: Inference done 716/2234. 0.1019 s / img. ETA=0:02:50
# [02/19 20:20:08 d2.evaluation.evaluator]: Inference done 764/2234. 0.1019 s / img. ETA=0:02:44
# [02/19 20:20:13 d2.evaluation.evaluator]: Inference done 812/2234. 0.1020 s / img. ETA=0:02:38
# [02/19 20:20:18 d2.evaluation.evaluator]: Inference done 860/2234. 0.1021 s / img. ETA=0:02:33
# [02/19 20:20:23 d2.evaluation.evaluator]: Inference done 908/2234. 0.1023 s / img. ETA=0:02:27
# [02/19 20:20:28 d2.evaluation.evaluator]: Inference done 955/2234. 0.1024 s / img. ETA=0:02:21
# [02/19 20:20:33 d2.evaluation.evaluator]: Inference done 1002/2234. 0.1025 s / img. ETA=0:02:16
48 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 20:22:48 d2.evaluation.coco_evaluation]: Saving results to ./ModelOutput/retinanet_R_101_FPN_3x_3/coco_instances_results.json
# [02/19 20:22:48 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.07 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.679
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/19 20:22:49 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 25.162 | 67.870 | 10.651 | 24.575 | 34.827 |  nan  |
# [02/19 20:22:49 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# OrderedDict([('bbox', {'AP': 25.16167270865654, 'AP50': 67.86966693852979, 'AP75': 10.650790344913531, 'APs': 24.574697814568346, 'APm': 34.826535348702095, 'APl': nan})])

# %%
# test
evaluator = COCOEvaluator('ssdd_test', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test')

print(inference_on_dataset(trainer.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# [02/19 20:23:00 d2.evaluation.coco_evaluation]: 'ssdd_test' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# WARNING [02/19 20:23:00 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/retinanet_R_101_FPN_3x_3/ssdd_test_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [02/19 20:23:00 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 2378         |
# |            |              |
# [02/19 20:23:00 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:23:00 d2.data.common]: Serializing 3000 elements to byte tensors and concatenating them all ...
# [02/19 20:23:00 d2.data.common]: Serialized dataset takes 0.53 MiB
# [02/19 20:23:00 d2.evaluation.evaluator]: Start inference on 3000 images
# [02/19 20:23:02 d2.evaluation.evaluator]: Inference done 11/3000. 0.1058 s / img. ETA=0:05:18
# [02/19 20:23:07 d2.evaluation.evaluator]: Inference done 58/3000. 0.1059 s / img. ETA=0:05:16
# [02/19 20:23:12 d2.evaluation.evaluator]: Inference done 104/3000. 0.1063 s / img. ETA=0:05:13
# [02/19 20:23:17 d2.evaluation.evaluator]: Inference done 150/3000. 0.1068 s / img. ETA=0:05:09
# [02/19 20:23:22 d2.evaluation.evaluator]: Inference done 196/3000. 0.1073 s / img. ETA=0:05:05
# [02/19 20:23:27 d2.evaluation.evaluator]: Inference done 241/3000. 0.1078 s / img. ETA=0:05:02
# [02/19 20:23:32 d2.evaluation.evaluator]: Inference done 286/3000. 0.1083 s / img. ETA=0:04:58
# [02/19 20:23:38 d2.evaluation.evaluator]: Inference done 332/3000. 0.1083 s / img. ETA=0:04:53
# [02/19 20:23:43 d2.evaluation.evaluator]: Inference done 378/3000. 0.1084 s / img. ETA=0:04:48
# [02/19 20:23:48 d2.evaluation.evaluator]: Inference done 424/3000. 0.1084 s / img. ETA=0:04:43
# [02/19 20:23:53 d2.evaluation.evaluator]: Inference done 470/3000. 0.1083 s / img. ETA=0:04:38
# [02/19 20:23:58 d2.evaluation.evaluator]: Inference done 516/3000. 0.1082 s / img. ETA=0:04:33
# [02/19 20:24:03 d2.evaluation.evaluator]: Inference done 562/3000. 0.1082 s / img. ETA=0:04:28
# [02/19 20:24:08 d2.evaluation.evaluator]: Inference done 609/3000. 0.1081 s / img. ETA=0:04:22
# [02/19 20:24:13 d2.evaluation.evaluator]: Inference done 656/3000. 0.1079 s / img. ETA=0:04:17
# [02/19 20:24:18 d2.evaluation.evaluator]: Inference done 703/3000. 0.1078 s / img. ETA=0:04:11
# [02/19 20:24:23 d2.evaluation.evaluator]: Inference done 750/3000. 0.1077 s / img. ETA=0:04:06
# [02/19 20:24:28 d2.evaluation.evaluator]: Inference done 797/3000. 0.1076 s / img. ETA=0:04:00
# [02/19 20:24:33 d2.evaluation.evaluator]: Inference done 844/3000. 0.1076 s / img. ETA=0:03:55
# [02/19 20:26:59 d2.evaluation.evaluator]: Inference done 2187/3000. 0.1074 s / img. ETA=0:01:28
# [02/19 20:27:05 d2.evaluation.evaluator]: Inference done 2233/3000. 0.1074 s / img. ETA=0:01:23
# [02/19 20:27:10 d2.evaluation.evaluator]: Inference done 2279/3000. 0.1074 s / img. ETA=0:01:18
# [02/19 20:27:15 d2.evaluation.evaluator]: Inference done 2325/3000. 0.1074 s / img. ETA=0:01:13
# [02/19 20:27:20 d2.evaluation.evaluator]: Inference done 2371/3000. 0.1074 s / img. ETA=0:01:08
# [02/19 20:27:25 d2.evaluation.evaluator]: Inference done 2416/3000. 0.1074 s / img. ETA=0:01:03
# [02/19 20:27:30 d2.evaluation.evaluator]: Inference done 2452/3000. 0.1074 s / img. ETA=0:01:00
# [02/19 20:27:35 d2.evaluation.evaluator]: Inference done 2498/3000. 0.1074 s / img. ETA=0:00:55
# [02/19 20:27:40 d2.evaluation.evaluator]: Inference done 2544/3000. 0.1074 s / img. ETA=0:00:49
# [02/19 20:27:45 d2.evaluation.evaluator]: Inference done 2590/3000. 0.1074 s / img. ETA=0:00:44
# [02/19 20:27:50 d2.evaluation.evaluator]: Inference done 2636/3000. 0.1074 s / img. ETA=0:00:39
# [02/19 20:27:55 d2.evaluation.evaluator]: Inference done 2683/3000. 0.1074 s / img. ETA=0:00:34
# [02/19 20:28:00 d2.evaluation.evaluator]: Inference done 2729/3000. 0.1074 s / img. ETA=0:00:29
# [02/19 20:28:05 d2.evaluation.evaluator]: Inference done 2775/3000. 0.1074 s / img. ETA=0:00:24
# [02/19 20:28:10 d2.evaluation.evaluator]: Inference done 2820/3000. 0.1074 s / img. ETA=0:00:19
# [02/19 20:28:15 d2.evaluation.evaluator]: Inference done 2864/3000. 0.1074 s / img. ETA=0:00:14
# [02/19 20:28:20 d2.evaluation.evaluator]: Inference done 2910/3000. 0.1074 s / img. ETA=0:00:09
# [02/19 20:28:25 d2.evaluation.evaluator]: Inference done 2957/3000. 0.1074 s / img. ETA=0:00:04
# [02/19 20:28:30 d2.evaluation.evaluator]: Total inference time: 0:05:28.494254 (0.109681 s / img per device, on 1 devices)
# [02/19 20:28:30 d2.evaluation.evaluator]: Total inference pure compute time: 0:05:21 (0.107365 s / img per device, on 1 devices)
# [02/19 20:28:30 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 20:28:30 d2.evaluation.coco_evaluation]: Saving results to ./ModelOutput/retinanet_R_101_FPN_3x_3/coco_instances_results.json
# [02/19 20:28:30 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.22 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.484
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.469
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/19 20:28:30 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 17.688 | 48.383 | 7.444  | 16.520 | 33.831 |  nan  |
# [02/19 20:28:30 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# OrderedDict([('bbox', {'AP': 17.687928654288456, 'AP50': 48.38283911525932, 'AP75': 7.444436173783828, 'APs': 16.519618112583824, 'APm': 33.83105322152693, 'APl': nan})])

# %%
# test_inshore
evaluator = COCOEvaluator('ssdd_test_inshore', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_inshore')

print(inference_on_dataset(trainer.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# [02/19 20:28:39 d2.evaluation.coco_evaluation]: 'ssdd_test_inshore' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# WARNING [02/19 20:28:39 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/retinanet_R_101_FPN_3x_3/ssdd_test_inshore_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [02/19 20:28:47 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 883          |
# |            |              |
# [02/19 20:28:47 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:28:47 d2.data.common]: Serializing 766 elements to byte tensors and concatenating them all ...
# [02/19 20:28:47 d2.data.common]: Serialized dataset takes 0.14 MiB
# [02/19 20:28:47 d2.evaluation.evaluator]: Start inference on 766 images
# [02/19 20:28:49 d2.evaluation.evaluator]: Inference done 11/766. 0.1062 s / img. ETA=0:01:20
# [02/19 20:28:54 d2.evaluation.evaluator]: Inference done 57/766. 0.1065 s / img. ETA=0:01:17
# [02/19 20:28:59 d2.evaluation.evaluator]: Inference done 103/766. 0.1070 s / img. ETA=0:01:12
# [02/19 20:29:04 d2.evaluation.evaluator]: Inference done 149/766. 0.1076 s / img. ETA=0:01:07
# [02/19 20:29:09 d2.evaluation.evaluator]: Inference done 194/766. 0.1081 s / img. ETA=0:01:02
# [02/19 20:29:14 d2.evaluation.evaluator]: Inference done 239/766. 0.1086 s / img. ETA=0:00:58
# [02/19 20:29:19 d2.evaluation.evaluator]: Inference done 284/766. 0.1089 s / img. ETA=0:00:53
# [02/19 20:29:24 d2.evaluation.evaluator]: Inference done 329/766. 0.1090 s / img. ETA=0:00:48
# [02/19 20:29:29 d2.evaluation.evaluator]: Inference done 375/766. 0.1091 s / img. ETA=0:00:43
# [02/19 20:29:34 d2.evaluation.evaluator]: Inference done 421/766. 0.1090 s / img. ETA=0:00:38
# [02/19 20:29:39 d2.evaluation.evaluator]: Inference done 467/766. 0.1089 s / img. ETA=0:00:33
# [02/19 20:29:44 d2.evaluation.evaluator]: Inference done 513/766. 0.1087 s / img. ETA=0:00:27
# [02/19 20:29:49 d2.evaluation.evaluator]: Inference done 560/766. 0.1086 s / img. ETA=0:00:22
# [02/19 20:29:54 d2.evaluation.evaluator]: Inference done 606/766. 0.1085 s / img. ETA=0:00:17
# [02/19 20:30:00 d2.evaluation.evaluator]: Inference done 653/766. 0.1083 s / img. ETA=0:00:12
# [02/19 20:30:05 d2.evaluation.evaluator]: Inference done 700/766. 0.1082 s / img. ETA=0:00:07
# [02/19 20:30:10 d2.evaluation.evaluator]: Inference done 747/766. 0.1082 s / img. ETA=0:00:02
# [02/19 20:30:12 d2.evaluation.evaluator]: Total inference time: 0:01:23.647401 (0.109918 s / img per device, on 1 devices)
# [02/19 20:30:12 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:22 (0.108113 s / img per device, on 1 devices)
# [02/19 20:30:12 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 20:30:12 d2.evaluation.coco_evaluation]: Saving results to ./ModelOutput/retinanet_R_101_FPN_3x_3/coco_instances_results.json
# [02/19 20:30:12 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [02/19 20:30:12 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm   |  APl  |
# |:-----:|:------:|:------:|:-----:|:------:|:-----:|
# | 4.919 | 14.875 | 1.812  | 4.675 | 27.023 |  nan  |
# [02/19 20:30:12 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# OrderedDict([('bbox', {'AP': 4.91881267669027, 'AP50': 14.87547810006008, 'AP75': 1.811866495678482, 'APs': 4.674518931443654, 'APm': 27.02329982856711, 'APl': nan})])

# %%
# %ls ./ModelOutput/retinanet_R_101_FPN_3x_3
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# coco_instances_results.json
# events.out.tfevents.1613323247.b87c8c2c21f5.144.0
# events.out.tfevents.1613765483.c6795579ebc0.145.0
# instances_predictions.pth
# last_checkpoint
# metrics.json
# model_0004999.pth
# model_0009999.pth
# model_0014999.pth
# model_0019999.pth
# model_0024999.pth
# model_0029999.pth
# model_0034999.pth
# model_0039999.pth
# model_0044999.pth
# model_0049999.pth
# model_0054999.pth
# model_0059999.pth
# model_0064999.pth
# model_0069999.pth
# model_final.pth
# predImages/
# predImages_eval/
# ssdd_test_coco_format.json
# ssdd_test_coco_format.json.lock
# ssdd_test_inshore_coco_format.json
# ssdd_test_inshore_coco_format.json.lock
# ssdd_test_offshore_coco_format.json
# ssdd_test_offshore_coco_format.json.lock
# ssdd_train_coco_format.json
# ssdd_train_coco_format.json.lock

# %% [markdown]
# # Evaluation using a Custom Evaluator
#
# detectron2.evaluation.coco_evaluation: https://detectron2.readthedocs.io/en/latest/_modules/detectron2/evaluation/coco_evaluation.html
#
# detectron2.evaluation: https://detectron2.readthedocs.io/en/latest/modules/evaluation.html#
#
# Evaluation: https://detectron2.readthedocs.io/en/latest/tutorials/evaluation.html
#
# Evaluation:
#
# https://github.com/facebookresearch/detectron2/blob/master/detectron2/evaluation/coco_evaluation.py
# https://github.com/facebookresearch/Detectron/blob/a6a835f5b8208c45d0dce217ce9bbda915f44df7/detectron/datasets/json_dataset_evaluator.py
#
# Concept:
#
# https://cs230.stanford.edu/section/7/
#
# https://jonathan-hui.medium.com/map-mean-average-precision-for-object-detection-45c121a31173

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from detectron2.structures import Boxes, BoxMode, pairwise_iou
from detectron2.data.datasets.coco import convert_to_coco_json
from detectron2.evaluation import DatasetEvaluator
from detectron2.utils.file_io import PathManager
from collections import OrderedDict
from pycocotools.coco import COCO
import itertools
import contextlib
import torch
import copy
import os
import io

# %%
def average_precision(correct, ground_truth):
  # correct contains True Positives (TP) and False Positives (FP)
  # ground_truth is the number of positive examples (TP + FN = GT)

  # precision = TP / (TP + FP)
  # recall = TP / (TP + FN) = TP / GT
  TP = 0
  FP = 0
  GT = ground_truth
  precision = []
  recall = []

  for i, c in enumerate(correct):
    if c:
      TP += 1
    else:
      FP += 1
    precision.append(TP / (TP + FP))
    if GT == 0:
      recall.append(0.0)
    else:
      recall.append(TP / GT)


  # Interpolate precision (replace each precision value with the maximum precision value to the right of that recall level)
  max = 0
  precision_interp = []

  for i, c in enumerate(reversed(precision)):
    if c > max:
      max = c
      precision_interp.append(c)
    else:
      precision_interp.append(max)
  
  precision_interp = list(reversed(precision_interp))


  # Calculate AP (Average Precision)
  AP = 0
  for i, c in enumerate(recall):
    if i == 0:
      continue
    AP += (recall[i] - recall[i-1]) * precision_interp[i]
  
  return recall, precision_interp, AP


# Test Case
test = [True, True, False, False, False, True, True, False, False, True]
recall, precision, AP = average_precision(test, 5)
assert AP == 0.5285714285714286
assert recall == [0.2, 0.4, 0.4, 0.4, 0.4, 0.6, 0.8, 0.8, 0.8, 1.0]
assert precision == [1.0, 
                    1.0, 
                    0.6666666666666666,
                    0.5714285714285714,
                    0.5714285714285714,
                    0.5714285714285714,
                    0.5714285714285714,
                    0.5,
                    0.5,
                    0.5]

# %%
class CustomEvaluator(DatasetEvaluator):
  def __init__(
        self,
        dataset_name,
        output_dir
  ):
    """
    Args:
        dataset_name (str): name of the dataset to be evaluated.
            It must have either the following corresponding metadata:

                "json_file": the path to the COCO format annotation

            Or it must be in detectron2's standard dataset format
            so it can be converted to COCO format automatically.
        output_dir (str): an output directory to dump all
            results predicted on the dataset. The dump contains two files:

            1. "instances_predictions.pth" (dataset_name + "_predictions.pth")
                a file that can be loaded with `torch.load` and
                contains all the results in the format they are produced by the model.
            2. "coco_instances_results.json" a json file in COCO's result format.
    """
    self._cpu_device = torch.device("cpu")
    self.dataset_name = dataset_name
    self._metadata = MetadataCatalog.get(dataset_name)
    self._output_dir = output_dir
    
    if not hasattr(self._metadata, "json_file"):
      cache_path = os.path.join(output_dir, f"{dataset_name}_coco_format.json")
      self._metadata.json_file = cache_path
      convert_to_coco_json(dataset_name, cache_path)

    json_file = PathManager.get_local_path(self._metadata.json_file)
    with contextlib.redirect_stdout(io.StringIO()):
        self._coco_api = COCO(json_file)

  def reset(self):
    """
    Preparation for a new round of evaluation.
    """
    self._predictions = []

  def process(self, inputs, outputs):
    """
    Process the pair of inputs and outputs.

    Args:
        inputs: the inputs to a COCO model (e.g., GeneralizedRCNN).
            It is a list of dict. Each dict corresponds to an image and
            contains keys like "height", "width", "file_name", "image_id".
        outputs: the outputs of a COCO model. It is a list of dicts with key
            "instances" that contains :class:`Instances`.
    """
    for input, output in zip(inputs, outputs):
      prediction = {"image_id": input["image_id"]}
      if "instances" in output:
          prediction["instances"] = output["instances"].to(self._cpu_device) 
      if len(prediction) > 1:
          self._predictions.append(prediction)
    
    if self._output_dir:
      PathManager.mkdirs(self._output_dir)
      file_path = os.path.join(self._output_dir,
                               self.dataset_name + "_predictions.pth")
#      file_path = os.path.join(self._output_dir, "instances_predictions.pth")
#      file_path = os.path.join(self._output_dir, f"{dataset_name}_predictions.pth") # NameError: name 'dataset_name' is not defined

      with PathManager.open(file_path, "wb") as f:
        torch.save(self._predictions, f)

  def evaluate(self):
    """
    Evaluate/summarize the performance, after processing all input/output pairs.
    Evaluates on the whole dataset.
    """
    iou_threshold = 0.5
    num_instances = 0
    num_pos = 0  # must be equal to GT
    gt_overlaps = []
#    ap = [] 
    scores = []
    correct = []

    if len(self._predictions) == 0:
      return {}, {}, {}

    # Loop over all instances in one image
    for prediction_dict in self._predictions:
      predictions = prediction_dict["instances"]
      num_instances += len(predictions)

      # Get scores of each instance, sort in descending order
      inds = predictions.get_fields()['scores'].sort(descending=True)[1]
      in_scores = predictions.get_fields()['scores']
      in_scores = in_scores[inds]
      
      # Get bbox of each instance, sort by score
      in_boxes = predictions.get_fields()['pred_boxes']
      in_boxes = in_boxes[inds]

      assert len(in_boxes) == len(in_scores) == len(predictions)

      # Retrieve corresponding ground truth boxes/labels
      ann_ids = self._coco_api.getAnnIds(imgIds=[prediction_dict["image_id"]])
      anno = self._coco_api.loadAnns(ann_ids)
      gt_boxes = [
          BoxMode.convert(obj["bbox"], BoxMode.XYWH_ABS, BoxMode.XYXY_ABS)
          for obj in anno
          if obj["iscrowd"] == 0
      ]
      gt_boxes = torch.as_tensor(gt_boxes).reshape(-1, 4)
      gt_boxes = Boxes(gt_boxes)

#      if len(predictions) == 0 or len(gt_boxes) == 0:
#        continue

      num_pos += len(gt_boxes)
      
      # Compute IOU for each instance-ground truth pair
      overlaps = pairwise_iou(in_boxes, gt_boxes)

      _gt_overlaps = torch.zeros(len(gt_boxes)) # stores iou for each gt box in one image
      _scores = torch.zeros(len(in_scores)) # stores iou for each proposal box (score) in one image

      # Ensure 1-1 mapping between prediction and gt boxes
      for j in range(min(len(predictions), len(gt_boxes))):
          # find which proposal box maximally covers each gt box
          # and get the iou amount of coverage for each gt box
          max_overlaps, argmax_overlaps = overlaps.max(dim=0)
          
          # find which gt box is 'best' covered (i.e. 'best' = most iou)
          gt_ovr, gt_ind = max_overlaps.max(dim=0)
          assert gt_ovr >= 0

          # find the proposal box that covers the best covered gt box
          box_ind = argmax_overlaps[gt_ind]

          # record the iou coverage of this gt box
          _gt_overlaps[j] = overlaps[box_ind, gt_ind]  # _gt_overlaps[gt_ind] ?
          assert _gt_overlaps[j] == gt_ovr  # _gt_overlaps[gt_ind] ?

          # record this iou coverage for score
          _scores[box_ind] = overlaps[box_ind, gt_ind]
          assert _scores[box_ind] == gt_ovr

          # mark the proposal box and the gt box as used
          overlaps[box_ind, :] = -1
          overlaps[:, gt_ind] = -1
      
      # update collectors
      _correct = (_scores >= iou_threshold).tolist() # stores TP/FP for each proposal box in one image

      assert len(_correct) == len(_scores) == len(predictions)
      
#      _, __, _ap = average_precision(_correct, len(gt_boxes))

      # append recorded iou coverage level
      gt_overlaps.append(_gt_overlaps)
      scores.append(in_scores)
      correct.append(_correct)
#      ap.append(_ap)


    # all images
    gt_overlaps = (
        torch.cat(gt_overlaps, dim=0) if len(gt_overlaps)
         else torch.zeros(0, dtype=torch.float32)
    )
    gt_overlaps, _ = torch.sort(gt_overlaps, descending = True)

    scores = (
        torch.cat(scores, dim=0) if len(scores)
         else torch.zeros(0, dtype=torch.float32)
    )
    scores, ind = torch.sort(scores, descending = True)
    
    # stores TP/FP for each proposal box in all images (in descending order of scores)
    correct = list(itertools.chain.from_iterable(correct))
    assert len(scores) == len(correct)
    correct = [correct[i] for i in ind.tolist()]

    # The following metrics are computed at iou_threshold
    GT = len(self._coco_api.getAnnIds())
    assert GT == num_pos

    TP = np.sum(np.array(correct))
    FP = len(correct) - TP
    assert (TP + FP) == num_instances
    FN = GT - TP

    Pd = TP / GT          # Detection probability
    Pf = FP / (TP + FP)   # false alarm
    Pm = FN / GT          # missed detection
    # assert (Pd + Pm) == 1

    recall = TP / (TP + FN)
    precision = TP / (TP + FP)
    F1 = 2 * (precision * recall) / (precision + recall)
#    meanAP = np.array(ap).mean()
    recalls, precisions, mAP = average_precision(correct, GT)

    plot = {"recalls": recalls, "precisions": precisions}
    hist = {"gt_overlap": gt_overlaps, "scores": scores}
    self._results = {
        "TP": TP,
        "FP": FP,
        "GT": GT,
        "FN": FN,
        "Pd": Pd,
        "Pf": Pf,
        "Pm": Pm,
        "recall": recall,
        "precision": precision,
        "mAP": mAP,
        "F1": F1
    }

    return copy.deepcopy(self._results), plot, hist

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

#val = './datasets/test/'

# %%
# test_inshore
custEval = CustomEvaluator('ssdd_test_inshore', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_inshore')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [02/19 20:30:39 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:30:39 d2.data.common]: Serializing 766 elements to byte tensors and concatenating them all ...
# [02/19 20:30:39 d2.data.common]: Serialized dataset takes 0.14 MiB
# [02/19 20:30:39 d2.evaluation.evaluator]: Start inference on 766 images
# [02/19 20:30:41 d2.evaluation.evaluator]: Inference done 11/766. 0.1042 s / img. ETA=0:01:22
# [02/19 20:30:46 d2.evaluation.evaluator]: Inference done 55/766. 0.1042 s / img. ETA=0:01:21
# [02/19 20:30:51 d2.evaluation.evaluator]: Inference done 97/766. 0.1043 s / img. ETA=0:01:18
# [02/19 20:30:56 d2.evaluation.evaluator]: Inference done 138/766. 0.1044 s / img. ETA=0:01:14
# [02/19 20:31:01 d2.evaluation.evaluator]: Inference done 178/766. 0.1046 s / img. ETA=0:01:11
# [02/19 20:31:06 d2.evaluation.evaluator]: Inference done 218/766. 0.1047 s / img. ETA=0:01:06
# [02/19 20:31:11 d2.evaluation.evaluator]: Inference done 256/766. 0.1047 s / img. ETA=0:01:03
# [02/19 20:31:16 d2.evaluation.evaluator]: Inference done 295/766. 0.1045 s / img. ETA=0:00:58
# [02/19 20:31:21 d2.evaluation.evaluator]: Inference done 331/766. 0.1043 s / img. ETA=0:00:55
# [02/19 20:31:26 d2.evaluation.evaluator]: Inference done 368/766. 0.1041 s / img. ETA=0:00:50
# [02/19 20:31:31 d2.evaluation.evaluator]: Inference done 403/766. 0.1039 s / img. ETA=0:00:46
# [02/19 20:31:36 d2.evaluation.evaluator]: Inference done 439/766. 0.1038 s / img. ETA=0:00:42
# [02/19 20:31:42 d2.evaluation.evaluator]: Inference done 473/766. 0.1037 s / img. ETA=0:00:38
# [02/19 20:31:47 d2.evaluation.evaluator]: Inference done 507/766. 0.1035 s / img. ETA=0:00:34
# [02/19 20:31:52 d2.evaluation.evaluator]: Inference done 540/766. 0.1034 s / img. ETA=0:00:30
# [02/19 20:31:57 d2.evaluation.evaluator]: Inference done 571/766. 0.1033 s / img. ETA=0:00:26
# [02/19 20:32:02 d2.evaluation.evaluator]: Inference done 604/766. 0.1032 s / img. ETA=0:00:22
# [02/19 20:32:07 d2.evaluation.evaluator]: Inference done 635/766. 0.1032 s / img. ETA=0:00:18
# [02/19 20:32:12 d2.evaluation.evaluator]: Inference done 666/766. 0.1031 s / img. ETA=0:00:13
# [02/19 20:32:17 d2.evaluation.evaluator]: Inference done 697/766. 0.1031 s / img. ETA=0:00:09
# [02/19 20:32:22 d2.evaluation.evaluator]: Inference done 728/766. 0.1031 s / img. ETA=0:00:05
# [02/19 20:32:27 d2.evaluation.evaluator]: Inference done 756/766. 0.1030 s / img. ETA=0:00:01
# [02/19 20:32:29 d2.evaluation.evaluator]: Total inference time: 0:01:48.777165 (0.142940 s / img per device, on 1 devices)
# [02/19 20:32:29 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:18 (0.103030 s / img per device, on 1 devices)

# %%
eval, plot, hist = custEval.evaluate()
eval
# Out:
# {'F1': 0.29397590361445786,
#  'FN': 700,
#  'FP': 179,
#  'GT': 883,
#  'Pd': 0.2072480181200453,
#  'Pf': 0.494475138121547,
#  'Pm': 0.7927519818799547,
#  'TP': 183,
#  'mAP': 0.14540213634151927,
#  'precision': 0.505524861878453,
#  'recall': 0.2072480181200453}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %%
# test_offshore
custEval = CustomEvaluator('ssdd_test_offshore', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_offshore')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [02/19 20:34:26 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:34:26 d2.data.common]: Serializing 2234 elements to byte tensors and concatenating them all ...
#
# [02/19 20:39:09 d2.evaluation.evaluator]: Inference done 1589/2234. 0.1002 s / img. ETA=0:01:54
# [02/19 20:39:14 d2.evaluation.evaluator]: Inference done 1609/2234. 0.1002 s / img. ETA=0:01:51
# [02/19 20:39:19 d2.evaluation.evaluator]: Inference done 1629/2234. 0.1002 s / img. ETA=0:01:48
# [02/19 20:39:24 d2.evaluation.evaluator]: Inference done 1649/2234. 0.1002 s / img. ETA=0:01:45
# [02/19 20:39:29 d2.evaluation.evaluator]: Inference done 1669/2234. 0.1002 s / img. ETA=0:01:42
# [02/19 20:39:34 d2.evaluation.evaluator]: Inference done 1689/2234. 0.1002 s / img. ETA=0:01:39
# [02/19 20:39:39 d2.evaluation.evaluator]: Inference done 1710/2234. 0.1002 s / img. ETA=0:01:35
# [02/19 20:39:45 d2.evaluation.evaluator]: Inference done 1730/2234. 0.1002 s / img. ETA=0:01:32
# [02/19 20:39:50 d2.evaluation.evaluator]: Inference done 1749/2234. 0.1002 s / img. ETA=0:01:29
# [02/19 20:39:55 d2.evaluation.evaluator]: Inference done 1768/2234. 0.1002 s / img. ETA=0:01:26
# [02/19 20:40:00 d2.evaluation.evaluator]: Inference done 1787/2234. 0.1002 s / img. ETA=0:01:23
# [02/19 20:40:05 d2.evaluation.evaluator]: Inference done 1806/2234. 0.1002 s / img. ETA=0:01:20
# [02/19 20:40:10 d2.evaluation.evaluator]: Inference done 1825/2234. 0.1002 s / img. ETA=0:01:17
# [02/19 20:40:15 d2.evaluation.evaluator]: Inference done 1844/2234. 0.1002 s / img. ETA=0:01:13
# [02/19 20:40:21 d2.evaluation.evaluator]: Inference done 1863/2234. 0.1002 s / img. ETA=0:01:10
# [02/19 20:40:26 d2.evaluation.evaluator]: Inference done 1881/2234. 0.1002 s / img. ETA=0:01:07
# [02/19 20:40:31 d2.evaluation.evaluator]: Inference done 1899/2234. 0.1002 s / img. ETA=0:01:04
# [02/19 20:40:36 d2.evaluation.evaluator]: Inference done 1917/2234. 0.1002 s / img. ETA=0:01:01
# [02/19 20:40:41 d2.evaluation.evaluator]: Inference done 1935/2234. 0.1002 s / img. ETA=0:00:57
# [02/19 20:40:46 d2.evaluation.evaluator]: Inference done 1953/2234. 0.1002 s / img. ETA=0:00:54
# [02/19 20:40:51 d2.evaluation.evaluator]: Inference done 1971/2234. 0.1002 s / img. ETA=0:00:51
# [02/19 20:40:57 d2.evaluation.evaluator]: Inference done 1990/2234. 0.1002 s / img. ETA=0:00:47
# [02/19 20:41:02 d2.evaluation.evaluator]: Inference done 2008/2234. 0.1002 s / img. ETA=0:00:44
# [02/19 20:41:07 d2.evaluation.evaluator]: Inference done 2025/2234. 0.1002 s / img. ETA=0:00:41
# [02/19 20:41:12 d2.evaluation.evaluator]: Inference done 2043/2234. 0.1002 s / img. ETA=0:00:37
# [02/19 20:41:17 d2.evaluation.evaluator]: Inference done 2060/2234. 0.1002 s / img. ETA=0:00:34
# [02/19 20:41:22 d2.evaluation.evaluator]: Inference done 2077/2234. 0.1002 s / img. ETA=0:00:31
# [02/19 20:41:28 d2.evaluation.evaluator]: Inference done 2095/2234. 0.1002 s / img. ETA=0:00:27
# [02/19 20:41:33 d2.evaluation.evaluator]: Inference done 2112/2234. 0.1002 s / img. ETA=0:00:24
# [02/19 20:41:38 d2.evaluation.evaluator]: Inference done 2129/2234. 0.1002 s / img. ETA=0:00:21
# [02/19 20:41:43 d2.evaluation.evaluator]: Inference done 2145/2234. 0.1002 s / img. ETA=0:00:18
# [02/19 20:41:48 d2.evaluation.evaluator]: Inference done 2162/2234. 0.1002 s / img. ETA=0:00:14
# [02/19 20:41:53 d2.evaluation.evaluator]: Inference done 2179/2234. 0.1002 s / img. ETA=0:00:11
# [02/19 20:41:59 d2.evaluation.evaluator]: Inference done 2196/2234. 0.1002 s / img. ETA=0:00:07
# [02/19 20:42:04 d2.evaluation.evaluator]: Inference done 2212/2234. 0.1002 s / img. ETA=0:00:04
# [02/19 20:42:09 d2.evaluation.evaluator]: Inference done 2229/2234. 0.1002 s / img. ETA=0:00:01
# [02/19 20:42:10 d2.evaluation.evaluator]: Total inference time: 0:07:43.250125 (0.207829 s / img per device, on 1 devices)
# [02/19 20:42:10 d2.evaluation.evaluator]: Total inference pure compute time: 0:03:43 (0.100208 s / img per device, on 1 devices)

# %%
eval, plot, hist = custEval.evaluate()
eval
# Out:
# {'F1': 0.787476979742173,
#  'FN': 426,
#  'FP': 151,
#  'GT': 1495,
#  'Pd': 0.7150501672240802,
#  'Pf': 0.12377049180327869,
#  'Pm': 0.28494983277591973,
#  'TP': 1069,
#  'mAP': 0.6798529725055216,
#  'precision': 0.8762295081967213,
#  'recall': 0.7150501672240802}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %%
# test
custEval = CustomEvaluator('ssdd_test', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [02/19 20:42:58 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:42:58 d2.data.common]: Serializing 3000 elements to byte tensors and concatenating them all ...
# [02/19 20:42:58 d2.data.common]: Serialized dataset takes 0.53 MiB
# [02/19 20:42:58 d2.evaluation.evaluator]: Start inference on 3000 images
# [02/19 20:42:59 d2.evaluation.evaluator]: Inference done 11/3000. 0.0991 s / img. ETA=0:05:21
# [02/19 20:43:04 d2.evaluation.evaluator]: Inference done 57/3000. 0.0995 s / img. ETA=0:05:21
# [02/19 20:43:09 d2.evaluation.evaluator]: Inference done 100/3000. 0.0994 s / img. ETA=0:05:27
# [02/19 20:43:14 d2.evaluation.evaluator]: Inference done 143/3000. 0.0994 s / img. ETA=0:05:26
# [02/19 20:43:19 d2.evaluation.evaluator]: Inference done 184/3000. 0.0994 s / img. ETA=0:05:26
# [02/19 20:43:24 d2.evaluation.evaluator]: Inference done 224/3000. 0.0994 s / img. ETA=0:05:27
# [02/19 20:43:29 d2.evaluation.evaluator]: Inference done 264/3000. 0.0994 s / img. ETA=0:05:26
# [02/19 20:43:34 d2.evaluation.evaluator]: Inference done 302/3000. 0.0995 s / img. ETA=0:05:26
# [02/19 20:43:39 d2.evaluation.evaluator]: Inference done 340/3000. 0.0995 s / img. ETA=0:05:26
# [02/19 20:43:44 d2.evaluation.evaluator]: Inference done 376/3000. 0.0996 s / img. ETA=0:05:25
# [02/19 20:43:50 d2.evaluation.evaluator]: Inference done 411/3000. 0.0997 s / img. ETA=0:05:25
# [02/19 20:43:55 d2.evaluation.evaluator]: Inference done 446/3000. 0.0997 s / img. ETA=0:05:25
# [02/19 20:48:41 d2.evaluation.evaluator]: Inference done 1803/3000. 0.1010 s / img. ETA=0:03:47
# [02/19 20:48:46 d2.evaluation.evaluator]: Inference done 1822/3000. 0.1010 s / img. ETA=0:03:45
# [02/19 20:48:51 d2.evaluation.evaluator]: Inference done 1841/3000. 0.1010 s / img. ETA=0:03:42
# [02/19 20:48:56 d2.evaluation.evaluator]: Inference done 1859/3000. 0.1010 s / img. ETA=0:03:40
# [02/19 20:49:01 d2.evaluation.evaluator]: Inference done 1878/3000. 0.1010 s / img. ETA=0:03:37
# [02/19 20:49:07 d2.evaluation.evaluator]: Inference done 1897/3000. 0.1010 s / img. ETA=0:03:34
# [02/19 20:49:12 d2.evaluation.evaluator]: Inference done 1916/3000. 0.1010 s / img. ETA=0:03:31
# [02/19 20:49:17 d2.evaluation.evaluator]: Inference done 1934/3000. 0.1009 s / img. ETA=0:03:29
# [02/19 20:49:22 d2.evaluation.evaluator]: Inference done 1952/3000. 0.1009 s / img. ETA=0:03:26
# [02/19 20:49:27 d2.evaluation.evaluator]: Inference done 1970/3000. 0.1009 s / img. ETA=0:03:23
# [02/19 20:49:32 d2.evaluation.evaluator]: Inference done 1988/3000. 0.1009 s / img. ETA=0:03:21
# [02/19 20:49:38 d2.evaluation.evaluator]: Inference done 2006/3000. 0.1009 s / img. ETA=0:03:18
# [02/19 20:49:43 d2.evaluation.evaluator]: Inference done 2024/3000. 0.1009 s / img. ETA=0:03:15
# [02/19 20:49:48 d2.evaluation.evaluator]: Inference done 2041/3000. 0.1009 s / img. ETA=0:03:12
# [02/19 20:49:53 d2.evaluation.evaluator]: Inference done 2058/3000. 0.1009 s / img. ETA=0:03:10
# [02/19 20:49:58 d2.evaluation.evaluator]: Inference done 2075/3000. 0.1009 s / img. ETA=0:03:07
# [02/19 20:50:04 d2.evaluation.evaluator]: Inference done 2092/3000. 0.1009 s / img. ETA=0:03:04
# [02/19 20:50:09 d2.evaluation.evaluator]: Inference done 2110/3000. 0.1009 s / img. ETA=0:03:01
# [02/19 20:50:14 d2.evaluation.evaluator]: Inference done 2127/3000. 0.1009 s / img. ETA=0:02:59
# [02/19 20:50:19 d2.evaluation.evaluator]: Inference done 2144/3000. 0.1009 s / img. ETA=0:02:56
# [02/19 20:50:24 d2.evaluation.evaluator]: Inference done 2161/3000. 0.1009 s / img. ETA=0:02:53
# [02/19 20:50:30 d2.evaluation.evaluator]: Inference done 2178/3000. 0.1009 s / img. ETA=0:02:50
# [02/19 20:50:35 d2.evaluation.evaluator]: Inference done 2195/3000. 0.1009 s / img. ETA=0:02:47
# [02/19 20:50:40 d2.evaluation.evaluator]: Inference done 2211/3000. 0.1009 s / img. ETA=0:02:44
# [02/19 20:50:45 d2.evaluation.evaluator]: Inference done 2228/3000. 0.1009 s / img. ETA=0:02:41
# [02/19 20:50:50 d2.evaluation.evaluator]: Inference done 2244/3000. 0.1009 s / img. ETA=0:02:39
# [02/19 20:50:55 d2.evaluation.evaluator]: Inference done 2260/3000. 0.1009 s / img. ETA=0:02:36
# [02/19 20:51:00 d2.evaluation.evaluator]: Inference done 2276/3000. 0.1009 s / img. ETA=0:02:33
# [02/19 20:53:25 d2.evaluation.evaluator]: Inference done 2717/3000. 0.1006 s / img. ETA=0:01:05
# [02/19 20:53:30 d2.evaluation.evaluator]: Inference done 2732/3000. 0.1006 s / img. ETA=0:01:02
# [02/19 20:53:35 d2.evaluation.evaluator]: Inference done 2747/3000. 0.1006 s / img. ETA=0:00:58
# [02/19 20:53:40 d2.evaluation.evaluator]: Inference done 2762/3000. 0.1006 s / img. ETA=0:00:55
# [02/19 20:53:46 d2.evaluation.evaluator]: Inference done 2777/3000. 0.1006 s / img. ETA=0:00:52
# [02/19 20:53:51 d2.evaluation.evaluator]: Inference done 2792/3000. 0.1006 s / img. ETA=0:00:48
# [02/19 20:53:56 d2.evaluation.evaluator]: Inference done 2807/3000. 0.1006 s / img. ETA=0:00:45
# [02/19 20:54:01 d2.evaluation.evaluator]: Inference done 2821/3000. 0.1006 s / img. ETA=0:00:42
# [02/19 20:54:07 d2.evaluation.evaluator]: Inference done 2836/3000. 0.1006 s / img. ETA=0:00:38
# [02/19 20:54:12 d2.evaluation.evaluator]: Inference done 2851/3000. 0.1006 s / img. ETA=0:00:35
# [02/19 20:54:17 d2.evaluation.evaluator]: Inference done 2866/3000. 0.1006 s / img. ETA=0:00:31
# [02/19 20:54:23 d2.evaluation.evaluator]: Inference done 2880/3000. 0.1006 s / img. ETA=0:00:28
# [02/19 20:54:28 d2.evaluation.evaluator]: Inference done 2894/3000. 0.1006 s / img. ETA=0:00:25
# [02/19 20:54:33 d2.evaluation.evaluator]: Inference done 2908/3000. 0.1005 s / img. ETA=0:00:22
# [02/19 20:54:38 d2.evaluation.evaluator]: Inference done 2922/3000. 0.1005 s / img. ETA=0:00:18
# [02/19 20:54:43 d2.evaluation.evaluator]: Inference done 2937/3000. 0.1005 s / img. ETA=0:00:15
# [02/19 20:54:49 d2.evaluation.evaluator]: Inference done 2951/3000. 0.1005 s / img. ETA=0:00:11
# [02/19 20:54:54 d2.evaluation.evaluator]: Inference done 2965/3000. 0.1005 s / img. ETA=0:00:08
# [02/19 20:54:59 d2.evaluation.evaluator]: Inference done 2979/3000. 0.1005 s / img. ETA=0:00:05
# [02/19 20:55:04 d2.evaluation.evaluator]: Inference done 2993/3000. 0.1005 s / img. ETA=0:00:01
# [02/19 20:55:07 d2.evaluation.evaluator]: Total inference time: 0:12:08.287899 (0.243168 s / img per device, on 1 devices)
# [02/19 20:55:07 d2.evaluation.evaluator]: Total inference pure compute time: 0:05:00 (0.100480 s / img per device, on 1 devices)

# %%
eval, plot, hist = custEval.evaluate()
eval
# Out:
# {'F1': 0.6323232323232324,
#  'FN': 1126,
#  'FP': 330,
#  'GT': 2378,
#  'Pd': 0.5264928511354079,
#  'Pf': 0.20859671302149177,
#  'Pm': 0.4735071488645921,
#  'TP': 1252,
#  'mAP': 0.4843548249495392,
#  'precision': 0.7914032869785083,
#  'recall': 0.5264928511354079}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %%
# train
custEval = CustomEvaluator('ssdd_train', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_train')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# WARNING [02/19 20:57:10 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/retinanet_R_101_FPN_3x_3/ssdd_train_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [02/19 20:57:10 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 20:57:10 d2.data.common]: Serializing 6000 elements to byte tensors and concatenating them all ...
# [02/19 20:57:10 d2.data.common]: Serialized dataset takes 1.01 MiB
# [02/19 20:57:10 d2.evaluation.evaluator]: Start inference on 6000 images
# [02/19 20:57:12 d2.evaluation.evaluator]: Inference done 11/6000. 0.0981 s / img. ETA=0:10:41
# [02/19 20:57:17 d2.evaluation.evaluator]: Inference done 56/6000. 0.0988 s / img. ETA=0:11:06
# [02/19 20:57:22 d2.evaluation.evaluator]: Inference done 98/6000. 0.0988 s / img. ETA=0:11:25
# [02/19 20:57:27 d2.evaluation.evaluator]: Inference done 141/6000. 0.0987 s / img. ETA=0:11:26
# [02/19 20:57:33 d2.evaluation.evaluator]: Inference done 181/6000. 0.0988 s / img. ETA=0:11:32
# [02/19 20:57:38 d2.evaluation.evaluator]: Inference done 221/6000. 0.0987 s / img. ETA=0:11:36
# [02/19 20:57:43 d2.evaluation.evaluator]: Inference done 258/6000. 0.0988 s / img. ETA=0:11:46
# [02/19 20:57:48 d2.evaluation.evaluator]: Inference done 294/6000. 0.0989 s / img. ETA=0:11:54
# [02/19 20:57:53 d2.evaluation.evaluator]: Inference done 330/6000. 0.0989 s / img. ETA=0:11:59
# [02/19 20:57:58 d2.evaluation.evaluator]: Inference done 365/6000. 0.0989 s / img. ETA=0:12:04
# [02/19 20:58:03 d2.evaluation.evaluator]: Inference done 400/6000. 0.0989 s / img. ETA=0:12:07
# [02/19 20:58:08 d2.evaluation.evaluator]: Inference done 433/6000. 0.0990 s / img. ETA=0:12:13
# [02/19 20:58:13 d2.evaluation.evaluator]: Inference done 466/6000. 0.0990 s / img. ETA=0:12:18
# [02/19 20:58:18 d2.evaluation.evaluator]: Inference done 498/6000. 0.0990 s / img. ETA=0:12:23
# [02/19 20:58:23 d2.evaluation.evaluator]: Inference done 530/6000. 0.0991 s / img. ETA=0:12:26
# [02/19 20:58:28 d2.evaluation.evaluator]: Inference done 560/6000. 0.0991 s / img. ETA=0:12:31
# [02/19 20:58:33 d2.evaluation.evaluator]: Inference done 590/6000. 0.0992 s / img. ETA=0:12:35
# [02/19 20:58:38 d2.evaluation.evaluator]: Inference done 620/6000. 0.0993 s / img. ETA=0:12:40
# [02/19 20:58:43 d2.evaluation.evaluator]: Inference done 649/6000. 0.0993 s / img. ETA=0:12:43
# [02/19 20:58:49 d2.evaluation.evaluator]: Inference done 678/6000. 0.0994 s / img. ETA=0:12:47
# [02/19 20:58:54 d2.evaluation.evaluator]: Inference done 708/6000. 0.0995 s / img. ETA=0:12:50
# [02/19 20:58:59 d2.evaluation.evaluator]: Inference done 737/6000. 0.0995 s / img. ETA=0:12:52
# [02/19 20:59:04 d2.evaluation.evaluator]: Inference done 764/6000. 0.0996 s / img. ETA=0:12:55
# [02/19 20:59:09 d2.evaluation.evaluator]: Inference done 791/6000. 0.0997 s / img. ETA=0:12:58
# [02/19 20:59:14 d2.evaluation.evaluator]: Inference done 817/6000. 0.0997 s / img. ETA=0:13:02
# [02/19 20:59:19 d2.evaluation.evaluator]: Inference done 842/6000. 0.0997 s / img. ETA=0:13:06
# [02/19 20:59:24 d2.evaluation.evaluator]: Inference done 867/6000. 0.0998 s / img. ETA=0:13:09
# [02/19 21:20:49 d2.evaluation.evaluator]: Inference done 4401/6000. 0.0998 s / img. ETA=0:08:35
# [02/19 21:20:55 d2.evaluation.evaluator]: Inference done 4411/6000. 0.0998 s / img. ETA=0:08:33
# [02/19 21:21:00 d2.evaluation.evaluator]: Inference done 4421/6000. 0.0998 s / img. ETA=0:08:30
# [02/19 21:21:05 d2.evaluation.evaluator]: Inference done 4430/6000. 0.0998 s / img. ETA=0:08:28
# [02/19 21:21:10 d2.evaluation.evaluator]: Inference done 4440/6000. 0.0998 s / img. ETA=0:08:26
# [02/19 21:21:16 d2.evaluation.evaluator]: Inference done 4450/6000. 0.0998 s / img. ETA=0:08:23
# [02/19 21:21:21 d2.evaluation.evaluator]: Inference done 4460/6000. 0.0998 s / img. ETA=0:08:20
# [02/19 21:21:26 d2.evaluation.evaluator]: Inference done 4470/6000. 0.0998 s / img. ETA=0:08:18
# [02/19 21:21:31 d2.evaluation.evaluator]: Inference done 4480/6000. 0.0998 s / img. ETA=0:08:15
# [02/19 21:21:37 d2.evaluation.evaluator]: Inference done 4490/6000. 0.0998 s / img. ETA=0:08:13
# [02/19 21:21:42 d2.evaluation.evaluator]: Inference done 4500/6000. 0.0998 s / img. ETA=0:08:10
# [02/19 21:21:47 d2.evaluation.evaluator]: Inference done 4509/6000. 0.0998 s / img. ETA=0:08:08
# [02/19 21:21:52 d2.evaluation.evaluator]: Inference done 4519/6000. 0.0998 s / img. ETA=0:08:05
# [02/19 21:21:58 d2.evaluation.evaluator]: Inference done 4529/6000. 0.0998 s / img. ETA=0:08:03
# [02/19 21:22:03 d2.evaluation.evaluator]: Inference done 4539/6000. 0.0998 s / img. ETA=0:08:00
# [02/19 21:22:08 d2.evaluation.evaluator]: Inference done 4549/6000. 0.0998 s / img. ETA=0:07:57
# [02/19 21:22:13 d2.evaluation.evaluator]: Inference done 4558/6000. 0.0998 s / img. ETA=0:07:55
# [02/19 21:22:19 d2.evaluation.evaluator]: Inference done 4568/6000. 0.0998 s / img. ETA=0:07:53
# [02/19 21:22:24 d2.evaluation.evaluator]: Inference done 4578/6000. 0.0998 s / img. ETA=0:07:50
# [02/19 21:22:30 d2.evaluation.evaluator]: Inference done 4588/6000. 0.0998 s / img. ETA=0:07:47
# [02/19 21:22:35 d2.evaluation.evaluator]: Inference done 4598/6000. 0.0998 s / img. ETA=0:07:45
# [02/19 21:22:40 d2.evaluation.evaluator]: Inference done 4607/6000. 0.0998 s / img. ETA=0:07:42
# [02/19 21:22:45 d2.evaluation.evaluator]: Inference done 4617/6000. 0.0997 s / img. ETA=0:07:39
# [02/19 21:22:51 d2.evaluation.evaluator]: Inference done 4626/6000. 0.0997 s / img. ETA=0:07:37
# [02/19 21:22:56 d2.evaluation.evaluator]: Inference done 4635/6000. 0.0997 s / img. ETA=0:07:35
# [02/19 21:23:01 d2.evaluation.evaluator]: Inference done 4645/6000. 0.0997 s / img. ETA=0:07:32
# [02/19 21:23:06 d2.evaluation.evaluator]: Inference done 4654/6000. 0.0997 s / img. ETA=0:07:30
# [02/19 21:35:16 d2.evaluation.evaluator]: Inference done 5832/6000. 0.0995 s / img. ETA=0:01:05
# [02/19 21:35:22 d2.evaluation.evaluator]: Inference done 5840/6000. 0.0995 s / img. ETA=0:01:02
# [02/19 21:35:27 d2.evaluation.evaluator]: Inference done 5848/6000. 0.0995 s / img. ETA=0:00:59
# [02/19 21:35:33 d2.evaluation.evaluator]: Inference done 5856/6000. 0.0995 s / img. ETA=0:00:56
# [02/19 21:35:38 d2.evaluation.evaluator]: Inference done 5864/6000. 0.0995 s / img. ETA=0:00:53
# [02/19 21:35:44 d2.evaluation.evaluator]: Inference done 5872/6000. 0.0995 s / img. ETA=0:00:50
# [02/19 21:35:49 d2.evaluation.evaluator]: Inference done 5880/6000. 0.0995 s / img. ETA=0:00:47
# [02/19 21:35:55 d2.evaluation.evaluator]: Inference done 5888/6000. 0.0995 s / img. ETA=0:00:44
# [02/19 21:36:00 d2.evaluation.evaluator]: Inference done 5896/6000. 0.0995 s / img. ETA=0:00:41
# [02/19 21:36:05 d2.evaluation.evaluator]: Inference done 5904/6000. 0.0995 s / img. ETA=0:00:37
# [02/19 21:36:11 d2.evaluation.evaluator]: Inference done 5912/6000. 0.0995 s / img. ETA=0:00:34
# [02/19 21:36:16 d2.evaluation.evaluator]: Inference done 5920/6000. 0.0995 s / img. ETA=0:00:31
# [02/19 21:36:22 d2.evaluation.evaluator]: Inference done 5928/6000. 0.0995 s / img. ETA=0:00:28
# [02/19 21:36:27 d2.evaluation.evaluator]: Inference done 5936/6000. 0.0995 s / img. ETA=0:00:25
# [02/19 21:36:33 d2.evaluation.evaluator]: Inference done 5944/6000. 0.0995 s / img. ETA=0:00:22
# [02/19 21:36:39 d2.evaluation.evaluator]: Inference done 5952/6000. 0.0995 s / img. ETA=0:00:19
# [02/19 21:36:44 d2.evaluation.evaluator]: Inference done 5960/6000. 0.0995 s / img. ETA=0:00:15
# [02/19 21:36:50 d2.evaluation.evaluator]: Inference done 5968/6000. 0.0995 s / img. ETA=0:00:12
# [02/19 21:36:55 d2.evaluation.evaluator]: Inference done 5976/6000. 0.0994 s / img. ETA=0:00:09
# [02/19 21:37:01 d2.evaluation.evaluator]: Inference done 5984/6000. 0.0994 s / img. ETA=0:00:06
# [02/19 21:37:06 d2.evaluation.evaluator]: Inference done 5992/6000. 0.0994 s / img. ETA=0:00:03
# [02/19 21:37:12 d2.evaluation.evaluator]: Inference done 6000/6000. 0.0994 s / img. ETA=0:00:00
# [02/19 21:37:12 d2.evaluation.evaluator]: Total inference time: 0:40:00.037877 (0.400340 s / img per device, on 1 devices)
# [02/19 21:37:12 d2.evaluation.evaluator]: Total inference pure compute time: 0:09:56 (0.099444 s / img per device, on 1 devices)

# %%
eval, plot, hist = custEval.evaluate()
eval
# Out:
# {'F1': 0.5619146722164412,
#  'FN': 1747,
#  'FP': 1200,
#  'GT': 3637,
#  'Pd': 0.5196590596645587,
#  'Pf': 0.3883495145631068,
#  'Pm': 0.4803409403354413,
#  'TP': 1890,
#  'mAP': 0.4220870996099196,
#  'precision': 0.6116504854368932,
#  'recall': 0.5196590596645587}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()
