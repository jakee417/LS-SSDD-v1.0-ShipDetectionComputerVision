# %% [markdown]
# # Resources and credit:
# - Detectron2 docs: https://detectron2.readthedocs.io/en/latest/index.html
# - Conceptual: https://medium.com/@hirotoschwert/digging-into-detectron-2-part-5-6e220d762f9
# - https://jonathan-hui.medium.com/map-mean-average-precision-for-object-detection-45c121a31173

# %% [markdown]
# # Imports
# *Standard from Detectron2's docs*

# %% [markdown]
# *Restart after executing this cell*

# %%
# install dependencies: 
# !pip install pyyaml==5.1
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
#assert torch.__version__.startswith("1.7")
# !gcc --version
# opencv is pre-installed on colab
exit(0)
# Out:
# Collecting pyyaml==5.1
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 10.4MB/s
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp37-cp37m-linux_x86_64.whl size=44074 sha256=ac4d4e645ea1935d74478d8a34b29dab33e92c7133a88a3233c460cf4f0c604c
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.1
# 1.8.0+cu101 True
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %% [markdown]
# *Restart after executing this cell*

# %%
# install detectron2: (Colab has CUDA 10.1 + torch 1.8)
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
import torch
#assert torch.__version__.startswith("1.8")   # need to manually install torch 1.8 if Colab changes its default version
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.8/index.html
# exit(0)  # After installation, you need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.8/index.html
# Collecting detectron2
#   Downloading https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.8/detectron2-0.4%2Bcu101-cp37-cp37m-linux_x86_64.whl (6.2MB)
#      |████████████████████████████████| 6.2MB 203kB/s
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.7/dist-packages (from detectron2) (4.41.1)
# Collecting fvcore<0.1.4,>=0.1.3
#   Downloading https://files.pythonhosted.org/packages/53/5a/21648e033fcb91d0b0b540425c7564e994b149b1d3ab8976ab44ea8e1b3f/fvcore-0.1.3.post20210311.tar.gz (47kB)
#      |████████████████████████████████| 51kB 5.9MB/s
# Collecting Pillow>=7.1
#   Downloading https://files.pythonhosted.org/packages/1f/6d/b719ae8e21660a6a962636896dc4b7d657ef451a3ab941516401846ac5cb/Pillow-8.1.2-cp37-cp37m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 18.1MB/s
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from detectron2) (2.0.2)
# Collecting omegaconf>=2
#   Downloading https://files.pythonhosted.org/packages/d0/eb/9d63ce09dd8aa85767c65668d5414958ea29648a0eec80a4a7d311ec2684/omegaconf-2.0.6-py3-none-any.whl
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from detectron2) (1.3.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from detectron2) (2.4.1)
# Collecting yacs>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl
# Collecting iopath>=0.1.2
#   Downloading https://files.pythonhosted.org/packages/a3/4d/969c3c078e434b91fa871eb7deb3280e2d502ac583ba1bae506f2ed71388/iopath-0.1.6.tar.gz
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from detectron2) (0.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from detectron2) (3.2.2)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.7/dist-packages (from detectron2) (1.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from detectron2) (0.8.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fvcore<0.1.4,>=0.1.3->detectron2) (1.19.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from fvcore<0.1.4,>=0.1.3->detectron2) (5.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot->detectron2) (2.4.7)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools>=2.0.2->detectron2) (0.29.22)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools>=2.0.2->detectron2) (54.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from omegaconf>=2->detectron2) (3.7.4.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.8.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.32.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (0.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.15.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (0.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (2.23.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (3.12.4)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard->detectron2) (0.36.2)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/82/22/e684c9e2e59b561dbe36538852e81849122c666c423448e3a5c99362c228/portalocker-2.2.1-py2.py3-none-any.whl
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->detectron2) (2.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->detectron2) (3.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.10)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->detectron2) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (3.1.0)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.3.post20210311-cp37-none-any.whl size=58461 sha256=c34f93361e1d04cd1a83f395ca6196c1b2f31a14525074258f54b66cc5c1459d
#   Stored in directory: /root/.cache/pip/wheels/bc/cc/93/e011d6b86d91631d948f9bda94d60b82b51302192eb8a688c8
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.6-cp37-none-any.whl size=18269 sha256=d12f9dc4aac1e367a4682373275f50f78accf13ab3df8ccdcebd1faa0e5031a9
#   Stored in directory: /root/.cache/pip/wheels/ff/87/55/7513122394822977f993e1798bfebb46730d6183df8db7b283
# Successfully built fvcore iopath
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: yacs, Pillow, portalocker, iopath, fvcore, omegaconf, detectron2
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# Successfully installed Pillow-8.1.2 detectron2-0.4+cu101 fvcore-0.1.3.post20210311 iopath-0.1.6 omegaconf-2.0.6 portalocker-2.2.1 yacs-0.1.8

# %% [markdown]
# # Registration
# *Register train, test, test_offshore, test_inshore datasets*

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
import matplotlib.pyplot as plt

# %%
# Function that retrieves a standard dataset compatible with detectron2
def get_dict(type):
  """ Returns a list[dict] containing information about the dataset """
  import pickle
  root = '/content/drive/MyDrive/SSDD/datasets/' + type + '/'
  with open(root + "standardDict.pkl", "rb") as input_file:
    return pickle.load(input_file)

# %%
# Global paths
datasets = '/content/drive/MyDrive/SSDD/datasets/'
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from detectron2.structures import BoxMode
# Register
for d in ["train", "test", "test_offshore", "test_inshore", "train/train_w_val", "train/validation", "train/toy"]:
    DatasetCatalog.register(d, lambda d=d: get_dict(d))
    MetadataCatalog.get(d).set(thing_classes=["ship"])

# %%
# Instances of metadata
train_metadata = MetadataCatalog.get('train')
test_metadata = MetadataCatalog.get('test')
train_w_val_metadata = MetadataCatalog.get('train/train_w_val')
validation_metadata = MetadataCatalog.get('train/validation')
toy_metadata = MetadataCatalog.get('train/toy')
test_offshore = MetadataCatalog.get('test_offshore')
train_offshore = MetadataCatalog.get('train_offshore')

# %% [markdown]
# # Model Loading
# *Load the model we want to predict with*

# %%
# Quick copy/paste of models
# "./ModelOutput/faster_rcnn_R_50_FPN_3x_1_23_2021_36000iters"
#"COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"

# %%
# %cd /content/drive/MyDrive/SSDD/
output = '/content/drive/MyDrive/SSDD/'
model_name = "./ModelOutput/Faster_RCNN_X_101_32x8d_FPN_3x_std_aug_copy_paste_mask_sched" # Replace w/ folder
# Out:
# /content/drive/MyDrive/SSDD

# %%
from detectron2.engine import DefaultTrainer
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")) # Replace w/ config
cfg.DATASETS.TRAIN = ("train",)
cfg.DATASETS.TEST = ()
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ship)
cfg.OUTPUT_DIR = model_name
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth") # Load custom weights
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5 # pg.23 of Zhang et al.
cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST  = 0.5 # pg.23 of Zhang et al.

# %% [markdown]
# ## Initialize Trainer
# *Hidden for brevity*

# %%
trainer = DefaultTrainer(cfg)
# IMPORTANT! Model loads from last_checkpoint file! Not cfg.MODEL.WEIGHTSS
trainer.resume_or_load(resume=True)
# Out:
# [03/14 20:27:36 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [03/14 20:28:10 d2.data.build]: Removed 4877 images with no usable annotations. 1123 images left.
# [03/14 20:28:11 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 3637         |
# |            |              |
# [03/14 20:28:11 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [03/14 20:28:11 d2.data.build]: Using training sampler TrainingSampler
# [03/14 20:28:11 d2.data.common]: Serializing 1123 elements to byte tensors and concatenating them all ...
# [03/14 20:28:11 d2.data.common]: Serialized dataset takes 0.34 MiB
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Custom Evaluator

# %% [markdown]
# Follows: https://cs230.stanford.edu/section/7/

# %%
from detectron2.structures import Boxes, BoxMode, pairwise_iou
from detectron2.data.datasets.coco import convert_to_coco_json
from detectron2.evaluation import DatasetEvaluator
from detectron2.utils.file_io import PathManager
from collections import OrderedDict
from pycocotools.coco import COCO
import itertools
import contextlib
import torch
import copy
import os
import io

# %%
def average_precision(correct, ground_truth): 
  # correct contains True Positives (TP) and False Positives (FP)
  # ground_truth is the number of positive examples (TP + FN = GT)

  # precision = TP / (TP + FP)
  # recall = TP / (TP + FN) = TP / GT
  TP = 0
  FP = 0
  GT = ground_truth
  precision = []
  recall = []

  for i, c in enumerate(correct):
    if c:
      TP += 1
    else:
      FP += 1
    precision.append(TP / (TP + FP))
    if GT == 0:
      recall.append(0.0)
    else:
      recall.append(TP / GT)

  # Interpolate precision (replace each precision value with the maximum
  # precision value to the right of that recall level)
  max = 0
  precision_interp = []

  for i, c in enumerate(reversed(precision)):
    if c > max:
      max = c
      precision_interp.append(c)
    else:
      precision_interp.append(max)
  
  precision_interp = list(reversed(precision_interp))


  # Calculate AP (Average Precision)
  AP = 0
  for i, c in enumerate(recall):
    if i == 0:
      continue
    AP += (recall[i] - recall[i-1]) * precision_interp[i]
  
  return recall, precision_interp, AP


# Test Case
test = [True, True, False, False, False, True, True, False, False, True]
recall, precision, AP = average_precision(test, 5)
assert AP == 0.5285714285714286
assert recall == [0.2, 0.4, 0.4, 0.4, 0.4, 0.6, 0.8, 0.8, 0.8, 1.0]
assert precision == [1.0, 
                    1.0, 
                    0.6666666666666666,
                    0.5714285714285714,
                    0.5714285714285714,
                    0.5714285714285714,
                    0.5714285714285714,
                    0.5,
                    0.5,
                    0.5]

# %%
class CustomEvaluator(DatasetEvaluator):
  def __init__(
        self,
        dataset_name,
        output_dir
    ):
      """
      Args:
          dataset_name (str): name of the dataset to be evaluated.
              It must have either the following corresponding metadata:

                  "json_file": the path to the COCO format annotation

              Or it must be in detectron2's standard dataset format
              so it can be converted to COCO format automatically.
          output_dir (str): an output directory to dump all
              results predicted on the dataset. The dump contains two files:

              1. "instances_predictions.pth" (dataset_name + "_predictions.pth")
                  a file that can be loaded with `torch.load` and
                  contains all the results in the format they are produced by the model.
              2. "coco_instances_results.json" a json file in COCO's result format.
      """
      self._cpu_device = torch.device("cpu")
      self.dataset_name = dataset_name
      self._metadata = MetadataCatalog.get(dataset_name)
      self._output_dir = output_dir
      if not hasattr(self._metadata, "json_file"):
        cache_path = os.path.join(output_dir, f"{dataset_name}_coco_format.json")
        self._metadata.json_file = cache_path
        convert_to_coco_json(dataset_name, cache_path)

      json_file = PathManager.get_local_path(self._metadata.json_file)
      with contextlib.redirect_stdout(io.StringIO()):
          self._coco_api = COCO(json_file)

  def reset(self):
    """
    Preparation for a new round of evaluation.
    """
    self._predictions = []

  def process(self, inputs, outputs):
    """
    Process the pair of inputs and outputs.
    """
    for input, output in zip(inputs, outputs):
      prediction = {"image_id": input["image_id"]}
      if "instances" in output:
          prediction["instances"] = output["instances"].to(self._cpu_device) 
      if len(prediction) > 1:
          self._predictions.append(prediction)
    if self._output_dir:
            PathManager.mkdirs(self._output_dir)
            file_path = os.path.join(self._output_dir,
                                     self.dataset_name + "_predictions.pth")
            with PathManager.open(file_path, "wb") as f:
                torch.save(self._predictions, f)

  def evaluate(self):
    """
    Evaluate/summarize the performance, after processing all input/output pairs.
    """
    iou_threshold = 0.5 # pg.23 of Zhang et al. 
    num_instances = 0
    num_pos = 0 # must be equal to GT
    gt_overlaps = []
    scores = []
    correct = []
    bad_images = []

    if len(self._predictions) == 0:
      return {}, {}, {}

    # Loop overall all instances in one image
    for prediction_dict in self._predictions:
      predictions = prediction_dict["instances"]
      num_instances += len(predictions)

      # Get scores of each instance, sort
      inds = predictions.get_fields()['scores'].sort(descending=True)[1]
      in_scores = predictions.get_fields()['scores']
      in_scores = in_scores[inds]
      
      # Get bbox of each instance, sort by score
      in_boxes = predictions.get_fields()['pred_boxes']
      in_boxes = in_boxes[inds]

      assert len(in_boxes) == len(in_scores) == len(predictions)

      # Retrieve corresponding ground truth boxes/labels
      ann_ids = self._coco_api.getAnnIds(imgIds=[prediction_dict["image_id"]])
      anno = self._coco_api.loadAnns(ann_ids)
      gt_boxes = [
          BoxMode.convert(obj["bbox"], BoxMode.XYWH_ABS, BoxMode.XYXY_ABS)
          for obj in anno
          if obj["iscrowd"] == 0
      ]
      gt_boxes = torch.as_tensor(gt_boxes).reshape(-1, 4)
      gt_boxes = Boxes(gt_boxes)

      num_pos += len(gt_boxes)

      # Compute IOU for each instance-ground truth pair
      overlaps = pairwise_iou(in_boxes, gt_boxes)

      _gt_overlaps = torch.zeros(len(gt_boxes)) # stores best pred/gt iou
      _scores = torch.zeros(len(in_scores)) # stores iou for each score
      
      # Ensure 1-1 mapping between prediction and gt boxes
      for j in range(min(len(predictions), len(gt_boxes))):
          # find which proposal box maximally covers each gt box
          # and get the iou amount of coverage for each gt box
          max_overlaps, argmax_overlaps = overlaps.max(dim=0)

          # find which gt box is 'best' covered (i.e. 'best' = most iou)
          gt_ovr, gt_ind = max_overlaps.max(dim=0)
          assert gt_ovr >= 0

          # find the proposal box that covers the best covered gt box
          box_ind = argmax_overlaps[gt_ind]

          # record the iou coverage of this gt box
          _gt_overlaps[j] = overlaps[box_ind, gt_ind]
          assert _gt_overlaps[j] == gt_ovr

          # record this iou coverage for score
          _scores[box_ind] =  overlaps[box_ind, gt_ind]
          assert _scores[box_ind] == gt_ovr

          # mark the proposal box and the gt box as used
          overlaps[box_ind, :] = -1
          overlaps[:, gt_ind] = -1

      # update collectors
      _correct = (_scores >= iou_threshold).tolist()

      if _correct and sum(np.invert(_correct)) > 0:
        bad_images.append(prediction_dict)
      assert len(_correct) == len(_scores) == len(predictions)
      scores.append(in_scores)
      correct.append(_correct)
      gt_overlaps.append(_gt_overlaps)

    gt_overlaps = (
        torch.cat(gt_overlaps, dim=0) if len(gt_overlaps)
         else torch.zeros(0, dtype=torch.float32)
    )
    gt_overlaps, _ = torch.sort(gt_overlaps, descending = True)

    scores = (
        torch.cat(scores, dim=0) if len(scores)
         else torch.zeros(0, dtype=torch.float32)
    )
    scores, ind = torch.sort(scores, descending = True)

    # stores TP/FP for each proposal box in all images 
    # (in descending order of scores)
    correct = list(itertools.chain.from_iterable(correct))
    assert len(scores) == len(correct)
    correct = [correct[i] for i in ind.tolist()]

    # The following metrics are computed at iou_threshold
    GT = len(self._coco_api.getAnnIds())
    assert GT == num_pos

    TP = np.sum(np.array(correct))
    FP = len(correct) - TP
    assert (TP + FP) == num_instances
    FN = GT - TP

    Pd = TP / GT          # Detection probability
    Pf = FP / (TP + FP)   # false alarm
    Pm = FN / GT          # missed detection

    recall = TP / (TP + FN)
    precision = TP / (TP + FP)
    F1 = 2*(precision * recall) / (precision + recall)
    recalls, precisions, mAP = average_precision(correct, GT)

    plot =  {"recalls": recalls, "precisions": precisions}
    hist = {"gt_overlap" : gt_overlaps, "scores": scores}
    self._results = {
        "TP": TP,
        "FP": FP,
        "GT": GT,
        "FN": FN,
        "Pd": Pd,
        "Pf": Pf,
        "Pm": Pm,
        "recall": recall,
        "precision": precision,
        "mAP": mAP,
        "F1": F1
    }
    return copy.deepcopy(self._results), plot, hist, bad_images

# %% [markdown]
# ### Training Predictions

# %%
from detectron2.evaluation import COCOEvaluator, DatasetEvaluators, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator('train/train_w_val', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
custEval = CustomEvaluator('train/train_w_val', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'train/train_w_val')
# Out:
# [03/13 23:04:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/13 23:04:32 d2.data.common]: Serializing 5100 elements to byte tensors and concatenating them all ...
# [03/13 23:04:32 d2.data.common]: Serialized dataset takes 0.86 MiB
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
inference = inference_on_dataset(trainer.model,
                                 val_loader,
                                 custEval)
# Out:
# [03/13 23:04:34 d2.evaluation.evaluator]: Start inference on 5100 images
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [03/13 23:04:37 d2.evaluation.evaluator]: Inference done 11/5100. 0.1453 s / img. ETA=0:12:57
# [03/13 23:04:42 d2.evaluation.evaluator]: Inference done 43/5100. 0.1453 s / img. ETA=0:13:11
# [03/13 23:04:47 d2.evaluation.evaluator]: Inference done 75/5100. 0.1451 s / img. ETA=0:13:14
# [03/13 23:04:52 d2.evaluation.evaluator]: Inference done 106/5100. 0.1452 s / img. ETA=0:13:16
# [03/13 23:04:57 d2.evaluation.evaluator]: Inference done 137/5100. 0.1452 s / img. ETA=0:13:19
# [03/13 23:05:02 d2.evaluation.evaluator]: Inference done 167/5100. 0.1452 s / img. ETA=0:13:21
# [03/13 23:05:07 d2.evaluation.evaluator]: Inference done 197/5100. 0.1453 s / img. ETA=0:13:23
# [03/13 23:05:12 d2.evaluation.evaluator]: Inference done 226/5100. 0.1454 s / img. ETA=0:13:25
# [03/13 23:05:17 d2.evaluation.evaluator]: Inference done 255/5100. 0.1455 s / img. ETA=0:13:27
# [03/13 23:05:22 d2.evaluation.evaluator]: Inference done 282/5100. 0.1457 s / img. ETA=0:13:32
# [03/13 23:05:27 d2.evaluation.evaluator]: Inference done 310/5100. 0.1457 s / img. ETA=0:13:33
# [03/13 23:05:32 d2.evaluation.evaluator]: Inference done 336/5100. 0.1456 s / img. ETA=0:13:38
# [03/13 23:05:38 d2.evaluation.evaluator]: Inference done 363/5100. 0.1456 s / img. ETA=0:13:39
# [03/13 23:05:43 d2.evaluation.evaluator]: Inference done 390/5100. 0.1456 s / img. ETA=0:13:40
# [03/13 23:05:48 d2.evaluation.evaluator]: Inference done 416/5100. 0.1456 s / img. ETA=0:13:42
# [03/13 23:05:53 d2.evaluation.evaluator]: Inference done 441/5100. 0.1456 s / img. ETA=0:13:45
# [03/13 23:05:58 d2.evaluation.evaluator]: Inference done 467/5100. 0.1456 s / img. ETA=0:13:46
# [03/13 23:06:03 d2.evaluation.evaluator]: Inference done 492/5100. 0.1456 s / img. ETA=0:13:47
# [03/13 23:06:08 d2.evaluation.evaluator]: Inference done 516/5100. 0.1456 s / img. ETA=0:13:49
# [03/13 23:06:13 d2.evaluation.evaluator]: Inference done 541/5100. 0.1457 s / img. ETA=0:13:50
# [03/13 23:06:18 d2.evaluation.evaluator]: Inference done 565/5100. 0.1457 s / img. ETA=0:13:52
# [03/13 23:06:23 d2.evaluation.evaluator]: Inference done 589/5100. 0.1457 s / img. ETA=0:13:53
# [03/13 23:06:29 d2.evaluation.evaluator]: Inference done 613/5100. 0.1457 s / img. ETA=0:13:54
# [03/13 23:06:34 d2.evaluation.evaluator]: Inference done 636/5100. 0.1457 s / img. ETA=0:13:55
# [03/13 23:06:39 d2.evaluation.evaluator]: Inference done 659/5100. 0.1457 s / img. ETA=0:13:56
# [03/13 23:41:03 d2.evaluation.evaluator]: Inference done 5005/5100. 0.1457 s / img. ETA=0:00:41
# [03/13 23:41:09 d2.evaluation.evaluator]: Inference done 5012/5100. 0.1457 s / img. ETA=0:00:38
# [03/13 23:41:14 d2.evaluation.evaluator]: Inference done 5019/5100. 0.1457 s / img. ETA=0:00:35
# [03/13 23:41:19 d2.evaluation.evaluator]: Inference done 5026/5100. 0.1457 s / img. ETA=0:00:32
# [03/13 23:41:24 d2.evaluation.evaluator]: Inference done 5033/5100. 0.1457 s / img. ETA=0:00:29
# [03/13 23:41:29 d2.evaluation.evaluator]: Inference done 5040/5100. 0.1457 s / img. ETA=0:00:26
# [03/13 23:41:34 d2.evaluation.evaluator]: Inference done 5047/5100. 0.1457 s / img. ETA=0:00:23
# [03/13 23:41:39 d2.evaluation.evaluator]: Inference done 5054/5100. 0.1457 s / img. ETA=0:00:20
# [03/13 23:41:44 d2.evaluation.evaluator]: Inference done 5061/5100. 0.1457 s / img. ETA=0:00:17
# [03/13 23:41:50 d2.evaluation.evaluator]: Inference done 5068/5100. 0.1457 s / img. ETA=0:00:14
# [03/13 23:41:55 d2.evaluation.evaluator]: Inference done 5075/5100. 0.1457 s / img. ETA=0:00:11
# [03/13 23:42:00 d2.evaluation.evaluator]: Inference done 5082/5100. 0.1457 s / img. ETA=0:00:07
# [03/13 23:42:05 d2.evaluation.evaluator]: Inference done 5089/5100. 0.1457 s / img. ETA=0:00:04
# [03/13 23:42:10 d2.evaluation.evaluator]: Inference done 5096/5100. 0.1457 s / img. ETA=0:00:01
# [03/13 23:42:13 d2.evaluation.evaluator]: Total inference time: 0:37:37.572768 (0.443096 s / img per device, on 1 devices)
# [03/13 23:42:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:12:22 (0.145684 s / img per device, on 1 devices)

# %%
# Alternatively, load predictions directly from file into custEval instance
#temp = custEval._predictions
temp = torch.load(os.path.join(cfg.OUTPUT_DIR, "train_predictions.pth"))
custEval._predictions = temp
# evaluator._predictions = temp
# evaluator.evaluate()

# %%
eval, plot, hist, bad_images = custEval.evaluate()
eval
# Out:
# {'F1': 0.650990099009901,
#  'FN': 1153,
#  'FP': 821,
#  'GT': 2994,
#  'Pd': 0.6148964595858384,
#  'Pf': 0.30841472577009765,
#  'Pm': 0.38510354041416167,
#  'TP': 1841,
#  'mAP': 0.5665607131318368,
#  'precision': 0.6915852742299023,
#  'recall': 0.6148964595858384}

# %%
# Precision Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.show()

# %%
# Scores of when gt_overlaps when (len(gt_box) != 0)
plt.hist(hist['scores'])
plt.show()

# %%
# iou values for all matching instances (no threshold)
plt.hist(hist['gt_overlap'])
plt.show()

# %% [markdown]
# ### Test Predictions

# %%
from detectron2.evaluation import COCOEvaluator, DatasetEvaluators, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator('test', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
custEval = CustomEvaluator('test', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'test')
# Out:
# [03/14 20:29:33 d2.evaluation.coco_evaluation]: 'test' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# WARNING [03/14 20:29:33 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/Faster_RCNN_X_101_32x8d_FPN_3x_std_aug_copy_paste_mask_sched/test_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [03/14 20:29:50 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 2378         |
# |            |              |
# [03/14 20:29:50 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/14 20:29:50 d2.data.common]: Serializing 3000 elements to byte tensors and concatenating them all ...
# [03/14 20:29:50 d2.data.common]: Serialized dataset takes 0.53 MiB
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
inference = inference_on_dataset(trainer.model,
                                 val_loader,
                                 custEval)
# Out:
# [03/13 23:48:49 d2.evaluation.evaluator]: Start inference on 3000 images
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [03/13 23:48:52 d2.evaluation.evaluator]: Inference done 11/3000. 0.1450 s / img. ETA=0:07:34
# [03/13 23:48:57 d2.evaluation.evaluator]: Inference done 43/3000. 0.1457 s / img. ETA=0:07:44
# [03/13 23:49:02 d2.evaluation.evaluator]: Inference done 74/3000. 0.1457 s / img. ETA=0:07:45
# [03/13 23:49:07 d2.evaluation.evaluator]: Inference done 105/3000. 0.1457 s / img. ETA=0:07:45
# [03/13 23:49:12 d2.evaluation.evaluator]: Inference done 135/3000. 0.1458 s / img. ETA=0:07:46
# [03/13 23:49:17 d2.evaluation.evaluator]: Inference done 164/3000. 0.1460 s / img. ETA=0:07:47
# [03/13 23:49:22 d2.evaluation.evaluator]: Inference done 192/3000. 0.1461 s / img. ETA=0:07:51
# [03/13 23:49:27 d2.evaluation.evaluator]: Inference done 220/3000. 0.1462 s / img. ETA=0:07:50
# [03/13 23:49:33 d2.evaluation.evaluator]: Inference done 248/3000. 0.1462 s / img. ETA=0:07:49
# [03/13 23:49:38 d2.evaluation.evaluator]: Inference done 276/3000. 0.1462 s / img. ETA=0:07:48
# [03/13 23:49:43 d2.evaluation.evaluator]: Inference done 303/3000. 0.1462 s / img. ETA=0:07:47
# [03/13 23:49:48 d2.evaluation.evaluator]: Inference done 330/3000. 0.1462 s / img. ETA=0:07:46
# [03/13 23:49:53 d2.evaluation.evaluator]: Inference done 356/3000. 0.1462 s / img. ETA=0:07:46
# [03/13 23:49:58 d2.evaluation.evaluator]: Inference done 382/3000. 0.1461 s / img. ETA=0:07:45
# [03/13 23:50:03 d2.evaluation.evaluator]: Inference done 408/3000. 0.1461 s / img. ETA=0:07:43
# [03/13 23:50:08 d2.evaluation.evaluator]: Inference done 432/3000. 0.1461 s / img. ETA=0:07:43
# [03/13 23:50:13 d2.evaluation.evaluator]: Inference done 458/3000. 0.1461 s / img. ETA=0:07:41
# [03/13 23:50:18 d2.evaluation.evaluator]: Inference done 483/3000. 0.1460 s / img. ETA=0:07:40
# [03/13 23:50:24 d2.evaluation.evaluator]: Inference done 508/3000. 0.1460 s / img. ETA=0:07:38
# [03/13 23:50:29 d2.evaluation.evaluator]: Inference done 532/3000. 0.1460 s / img. ETA=0:07:37
# [03/13 23:50:34 d2.evaluation.evaluator]: Inference done 556/3000. 0.1460 s / img. ETA=0:07:35
# [03/13 23:50:39 d2.evaluation.evaluator]: Inference done 579/3000. 0.1460 s / img. ETA=0:07:34
# [03/13 23:50:44 d2.evaluation.evaluator]: Inference done 602/3000. 0.1460 s / img. ETA=0:07:33
# [03/13 23:50:49 d2.evaluation.evaluator]: Inference done 625/3000. 0.1460 s / img. ETA=0:07:32
# [03/13 23:50:54 d2.evaluation.evaluator]: Inference done 647/3000. 0.1459 s / img. ETA=0:07:31
# [03/13 23:55:42 d2.evaluation.evaluator]: Inference done 1630/3000. 0.1457 s / img. ETA=0:05:46
# [03/13 23:55:47 d2.evaluation.evaluator]: Inference done 1644/3000. 0.1457 s / img. ETA=0:05:44
# [03/13 23:55:52 d2.evaluation.evaluator]: Inference done 1658/3000. 0.1457 s / img. ETA=0:05:41
# [03/13 23:55:58 d2.evaluation.evaluator]: Inference done 1673/3000. 0.1457 s / img. ETA=0:05:39
# [03/13 23:56:03 d2.evaluation.evaluator]: Inference done 1687/3000. 0.1457 s / img. ETA=0:05:36
# [03/13 23:56:08 d2.evaluation.evaluator]: Inference done 1701/3000. 0.1457 s / img. ETA=0:05:34
# [03/13 23:56:13 d2.evaluation.evaluator]: Inference done 1716/3000. 0.1457 s / img. ETA=0:05:31
# [03/13 23:56:18 d2.evaluation.evaluator]: Inference done 1731/3000. 0.1457 s / img. ETA=0:05:28
# [03/13 23:56:24 d2.evaluation.evaluator]: Inference done 1745/3000. 0.1457 s / img. ETA=0:05:26
# [03/13 23:56:29 d2.evaluation.evaluator]: Inference done 1759/3000. 0.1457 s / img. ETA=0:05:23
# [03/13 23:56:34 d2.evaluation.evaluator]: Inference done 1773/3000. 0.1457 s / img. ETA=0:05:21
# [03/13 23:56:39 d2.evaluation.evaluator]: Inference done 1787/3000. 0.1457 s / img. ETA=0:05:18
# [03/13 23:56:44 d2.evaluation.evaluator]: Inference done 1801/3000. 0.1457 s / img. ETA=0:05:15
# [03/13 23:56:49 d2.evaluation.evaluator]: Inference done 1815/3000. 0.1457 s / img. ETA=0:05:13
# [03/13 23:56:55 d2.evaluation.evaluator]: Inference done 1829/3000. 0.1457 s / img. ETA=0:05:10
# [03/13 23:57:00 d2.evaluation.evaluator]: Inference done 1843/3000. 0.1457 s / img. ETA=0:05:07
# [03/13 23:57:05 d2.evaluation.evaluator]: Inference done 1857/3000. 0.1457 s / img. ETA=0:05:04
# [03/13 23:57:10 d2.evaluation.evaluator]: Inference done 1871/3000. 0.1457 s / img. ETA=0:05:02
# [03/13 23:57:15 d2.evaluation.evaluator]: Inference done 1884/3000. 0.1456 s / img. ETA=0:04:59
# [03/13 23:57:21 d2.evaluation.evaluator]: Inference done 1898/3000. 0.1456 s / img. ETA=0:04:56
# [03/13 23:57:26 d2.evaluation.evaluator]: Inference done 1911/3000. 0.1456 s / img. ETA=0:04:54
# [03/13 23:57:31 d2.evaluation.evaluator]: Inference done 1924/3000. 0.1456 s / img. ETA=0:04:51
# [03/13 23:57:36 d2.evaluation.evaluator]: Inference done 1938/3000. 0.1456 s / img. ETA=0:04:48
# [03/13 23:57:42 d2.evaluation.evaluator]: Inference done 1952/3000. 0.1456 s / img. ETA=0:04:45
# [03/13 23:57:47 d2.evaluation.evaluator]: Inference done 1965/3000. 0.1456 s / img. ETA=0:04:42
# [03/13 23:57:52 d2.evaluation.evaluator]: Inference done 1978/3000. 0.1456 s / img. ETA=0:04:40
# [03/13 23:57:57 d2.evaluation.evaluator]: Inference done 1991/3000. 0.1456 s / img. ETA=0:04:37
# [03/13 23:58:02 d2.evaluation.evaluator]: Inference done 2004/3000. 0.1456 s / img. ETA=0:04:34
# [03/13 23:58:07 d2.evaluation.evaluator]: Inference done 2017/3000. 0.1456 s / img. ETA=0:04:31
# [03/13 23:58:12 d2.evaluation.evaluator]: Inference done 2030/3000. 0.1456 s / img. ETA=0:04:28
# [03/13 23:58:18 d2.evaluation.evaluator]: Inference done 2043/3000. 0.1456 s / img. ETA=0:04:25
# [03/13 23:58:23 d2.evaluation.evaluator]: Inference done 2056/3000. 0.1456 s / img. ETA=0:04:23
# [03/13 23:58:28 d2.evaluation.evaluator]: Inference done 2069/3000. 0.1456 s / img. ETA=0:04:20
# [03/13 23:58:33 d2.evaluation.evaluator]: Inference done 2082/3000. 0.1456 s / img. ETA=0:04:17
# [03/13 23:58:39 d2.evaluation.evaluator]: Inference done 2095/3000. 0.1456 s / img. ETA=0:04:14
# [03/13 23:58:44 d2.evaluation.evaluator]: Inference done 2108/3000. 0.1456 s / img. ETA=0:04:11
# [03/13 23:58:49 d2.evaluation.evaluator]: Inference done 2121/3000. 0.1456 s / img. ETA=0:04:08
# [03/13 23:58:55 d2.evaluation.evaluator]: Inference done 2134/3000. 0.1456 s / img. ETA=0:04:05
# [03/13 23:59:00 d2.evaluation.evaluator]: Inference done 2147/3000. 0.1456 s / img. ETA=0:04:02
# [03/13 23:59:05 d2.evaluation.evaluator]: Inference done 2160/3000. 0.1456 s / img. ETA=0:03:59
# [03/13 23:59:10 d2.evaluation.evaluator]: Inference done 2172/3000. 0.1456 s / img. ETA=0:03:56
# [03/13 23:59:15 d2.evaluation.evaluator]: Inference done 2184/3000. 0.1456 s / img. ETA=0:03:53
# [03/13 23:59:20 d2.evaluation.evaluator]: Inference done 2196/3000. 0.1456 s / img. ETA=0:03:50
# [03/13 23:59:25 d2.evaluation.evaluator]: Inference done 2208/3000. 0.1456 s / img. ETA=0:03:48
# [03/13 23:59:30 d2.evaluation.evaluator]: Inference done 2220/3000. 0.1456 s / img. ETA=0:03:45
# [03/13 23:59:36 d2.evaluation.evaluator]: Inference done 2232/3000. 0.1456 s / img. ETA=0:03:42
# [03/13 23:59:41 d2.evaluation.evaluator]: Inference done 2244/3000. 0.1456 s / img. ETA=0:03:39
# [03/13 23:59:46 d2.evaluation.evaluator]: Inference done 2256/3000. 0.1456 s / img. ETA=0:03:36
# [03/13 23:59:51 d2.evaluation.evaluator]: Inference done 2268/3000. 0.1456 s / img. ETA=0:03:33
# [03/13 23:59:56 d2.evaluation.evaluator]: Inference done 2280/3000. 0.1456 s / img. ETA=0:03:30
# [03/14 00:00:01 d2.evaluation.evaluator]: Inference done 2292/3000. 0.1456 s / img. ETA=0:03:27
# [03/14 00:00:07 d2.evaluation.evaluator]: Inference done 2304/3000. 0.1456 s / img. ETA=0:03:24
# [03/14 00:00:12 d2.evaluation.evaluator]: Inference done 2316/3000. 0.1456 s / img. ETA=0:03:21
# [03/14 00:00:17 d2.evaluation.evaluator]: Inference done 2328/3000. 0.1456 s / img. ETA=0:03:18
# [03/14 00:00:22 d2.evaluation.evaluator]: Inference done 2340/3000. 0.1456 s / img. ETA=0:03:15
# [03/14 00:00:28 d2.evaluation.evaluator]: Inference done 2352/3000. 0.1456 s / img. ETA=0:03:12
# [03/14 00:00:33 d2.evaluation.evaluator]: Inference done 2364/3000. 0.1456 s / img. ETA=0:03:09
# [03/14 00:00:38 d2.evaluation.evaluator]: Inference done 2376/3000. 0.1456 s / img. ETA=0:03:06
# [03/14 00:00:43 d2.evaluation.evaluator]: Inference done 2388/3000. 0.1456 s / img. ETA=0:03:02
# [03/14 00:00:49 d2.evaluation.evaluator]: Inference done 2400/3000. 0.1456 s / img. ETA=0:02:59
# [03/14 00:00:54 d2.evaluation.evaluator]: Inference done 2411/3000. 0.1456 s / img. ETA=0:02:56
# [03/14 00:00:59 d2.evaluation.evaluator]: Inference done 2423/3000. 0.1456 s / img. ETA=0:02:53
# [03/14 00:01:04 d2.evaluation.evaluator]: Inference done 2435/3000. 0.1456 s / img. ETA=0:02:50
# [03/14 00:01:10 d2.evaluation.evaluator]: Inference done 2447/3000. 0.1456 s / img. ETA=0:02:47
# [03/14 00:01:15 d2.evaluation.evaluator]: Inference done 2459/3000. 0.1456 s / img. ETA=0:02:44
# [03/14 00:01:21 d2.evaluation.evaluator]: Inference done 2471/3000. 0.1456 s / img. ETA=0:02:40
# [03/14 00:01:26 d2.evaluation.evaluator]: Inference done 2483/3000. 0.1456 s / img. ETA=0:02:37
# [03/14 00:01:31 d2.evaluation.evaluator]: Inference done 2495/3000. 0.1456 s / img. ETA=0:02:34
# [03/14 00:01:37 d2.evaluation.evaluator]: Inference done 2506/3000. 0.1456 s / img. ETA=0:02:31
# [03/14 00:01:42 d2.evaluation.evaluator]: Inference done 2517/3000. 0.1456 s / img. ETA=0:02:28
# [03/14 00:01:47 d2.evaluation.evaluator]: Inference done 2528/3000. 0.1456 s / img. ETA=0:02:25
# [03/14 00:01:52 d2.evaluation.evaluator]: Inference done 2539/3000. 0.1456 s / img. ETA=0:02:22
# [03/14 00:01:57 d2.evaluation.evaluator]: Inference done 2551/3000. 0.1456 s / img. ETA=0:02:18
# [03/14 00:02:02 d2.evaluation.evaluator]: Inference done 2562/3000. 0.1456 s / img. ETA=0:02:15
# [03/14 00:02:08 d2.evaluation.evaluator]: Inference done 2573/3000. 0.1456 s / img. ETA=0:02:12
# [03/14 00:02:13 d2.evaluation.evaluator]: Inference done 2584/3000. 0.1456 s / img. ETA=0:02:09
# [03/14 00:02:18 d2.evaluation.evaluator]: Inference done 2595/3000. 0.1456 s / img. ETA=0:02:06
# [03/14 00:02:23 d2.evaluation.evaluator]: Inference done 2606/3000. 0.1456 s / img. ETA=0:02:03
# [03/14 00:02:28 d2.evaluation.evaluator]: Inference done 2617/3000. 0.1456 s / img. ETA=0:01:59
# [03/14 00:02:33 d2.evaluation.evaluator]: Inference done 2628/3000. 0.1456 s / img. ETA=0:01:56
# [03/14 00:02:39 d2.evaluation.evaluator]: Inference done 2639/3000. 0.1456 s / img. ETA=0:01:53
# [03/14 00:02:44 d2.evaluation.evaluator]: Inference done 2650/3000. 0.1456 s / img. ETA=0:01:50
# [03/14 00:02:49 d2.evaluation.evaluator]: Inference done 2661/3000. 0.1456 s / img. ETA=0:01:46
# [03/14 00:02:54 d2.evaluation.evaluator]: Inference done 2672/3000. 0.1456 s / img. ETA=0:01:43
# [03/14 00:03:00 d2.evaluation.evaluator]: Inference done 2683/3000. 0.1456 s / img. ETA=0:01:40
# [03/14 00:03:05 d2.evaluation.evaluator]: Inference done 2694/3000. 0.1456 s / img. ETA=0:01:37
# [03/14 00:03:10 d2.evaluation.evaluator]: Inference done 2705/3000. 0.1456 s / img. ETA=0:01:33
# [03/14 00:03:15 d2.evaluation.evaluator]: Inference done 2716/3000. 0.1456 s / img. ETA=0:01:30
# [03/14 00:03:21 d2.evaluation.evaluator]: Inference done 2727/3000. 0.1456 s / img. ETA=0:01:27
# [03/14 00:03:26 d2.evaluation.evaluator]: Inference done 2738/3000. 0.1456 s / img. ETA=0:01:23
# [03/14 00:03:31 d2.evaluation.evaluator]: Inference done 2749/3000. 0.1456 s / img. ETA=0:01:20
# [03/14 00:03:37 d2.evaluation.evaluator]: Inference done 2760/3000. 0.1456 s / img. ETA=0:01:17
# [03/14 00:03:42 d2.evaluation.evaluator]: Inference done 2770/3000. 0.1456 s / img. ETA=0:01:14
# [03/14 00:03:47 d2.evaluation.evaluator]: Inference done 2781/3000. 0.1456 s / img. ETA=0:01:10
# [03/14 00:03:52 d2.evaluation.evaluator]: Inference done 2791/3000. 0.1456 s / img. ETA=0:01:07
# [03/14 00:03:57 d2.evaluation.evaluator]: Inference done 2802/3000. 0.1456 s / img. ETA=0:01:04
# [03/14 00:04:02 d2.evaluation.evaluator]: Inference done 2812/3000. 0.1456 s / img. ETA=0:01:01
# [03/14 00:04:08 d2.evaluation.evaluator]: Inference done 2823/3000. 0.1456 s / img. ETA=0:00:57
# [03/14 00:04:13 d2.evaluation.evaluator]: Inference done 2834/3000. 0.1456 s / img. ETA=0:00:54
# [03/14 00:04:18 d2.evaluation.evaluator]: Inference done 2844/3000. 0.1456 s / img. ETA=0:00:50
# [03/14 00:04:24 d2.evaluation.evaluator]: Inference done 2855/3000. 0.1456 s / img. ETA=0:00:47
# [03/14 00:04:29 d2.evaluation.evaluator]: Inference done 2866/3000. 0.1456 s / img. ETA=0:00:43
# [03/14 00:04:34 d2.evaluation.evaluator]: Inference done 2876/3000. 0.1456 s / img. ETA=0:00:40
# [03/14 00:04:40 d2.evaluation.evaluator]: Inference done 2887/3000. 0.1456 s / img. ETA=0:00:37
# [03/14 00:04:45 d2.evaluation.evaluator]: Inference done 2898/3000. 0.1456 s / img. ETA=0:00:33
# [03/14 00:04:50 d2.evaluation.evaluator]: Inference done 2908/3000. 0.1456 s / img. ETA=0:00:30
# [03/14 00:04:56 d2.evaluation.evaluator]: Inference done 2919/3000. 0.1456 s / img. ETA=0:00:26
# [03/14 00:05:02 d2.evaluation.evaluator]: Inference done 2930/3000. 0.1456 s / img. ETA=0:00:23
# [03/14 00:05:07 d2.evaluation.evaluator]: Inference done 2940/3000. 0.1456 s / img. ETA=0:00:19
# [03/14 00:05:12 d2.evaluation.evaluator]: Inference done 2950/3000. 0.1456 s / img. ETA=0:00:16
# [03/14 00:05:17 d2.evaluation.evaluator]: Inference done 2960/3000. 0.1456 s / img. ETA=0:00:13
# [03/14 00:05:22 d2.evaluation.evaluator]: Inference done 2970/3000. 0.1456 s / img. ETA=0:00:10
# [03/14 00:05:27 d2.evaluation.evaluator]: Inference done 2980/3000. 0.1456 s / img. ETA=0:00:06
# [03/14 00:05:32 d2.evaluation.evaluator]: Inference done 2990/3000. 0.1455 s / img. ETA=0:00:03
# [03/14 00:05:37 d2.evaluation.evaluator]: Inference done 3000/3000. 0.1455 s / img. ETA=0:00:00
# [03/14 00:05:37 d2.evaluation.evaluator]: Total inference time: 0:16:46.372407 (0.336017 s / img per device, on 1 devices)
# [03/14 00:05:37 d2.evaluation.evaluator]: Total inference pure compute time: 0:07:15 (0.145544 s / img per device, on 1 devices)

# %%
# Alternatively, load predictions directly from file into custEval instance
#temp = custEval._predictions
temp = torch.load(os.path.join(cfg.OUTPUT_DIR, "test_predictions.pth"))
custEval._predictions = temp
# evaluator._predictions = temp
# evaluator.evaluate()

# %%
eval, plot, hist, bad_images = custEval.evaluate()
eval
# Out:
# {'F1': 0.7634711101493183,
#  'FN': 614,
#  'FP': 479,
#  'GT': 2378,
#  'Pd': 0.7417998317914214,
#  'Pf': 0.2135532768613464,
#  'Pm': 0.25820016820857866,
#  'TP': 1764,
#  'mAP': 0.7137722177915448,
#  'precision': 0.7864467231386536,
#  'recall': 0.7417998317914214}

# %%
# Precision Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
# Scores of when gt_overlaps when (len(gt_box) != 0)
plt.hist(hist['scores'])
plt.xlabel('Confidence Score')
plt.ylabel('Count')
plt.show()

# %%
# iou values for all matching instances (no threshold)
plt.hist(hist['gt_overlap'])
plt.xlabel('IOU between Predictions and Ground-Truth')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Visualization
# *Output images where predictions are wrong for error analysis*

# %%
predictor = DefaultPredictor(cfg)

# %%
dataset_dicts = get_dict("test")
bad_images_ind = [i['image_id'] for i in bad_images]
# Filter out pics w/o annotations
dataset_dicts_anns = []
for i in dataset_dicts:
  # Change this depending if you want incorrect predictions
  # or correct predictions for a writeup
  if i['image_id'] not in bad_images_ind:
    dataset_dicts_anns.append(i)

# %%
len(dataset_dicts_anns)
# Out:
# 2704

# %%
def printImage(ann, metadata, predictor = None, predFlag = False):
  from detectron2.utils.visualizer import Visualizer
  im = cv2.imread(ann["file_name"])
  v = Visualizer(im[:, :, ::-1], 
                 metadata=metadata, 
                 scale=0.5)
  if predFlag:
    outputs = predictor(im)  
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  else:
    out = v.draw_dataset_dict(ann)
  image = out.get_image()[:, :, ::-1]
  return image

# %%
from cv2 import hconcat
num_samples = len(dataset_dicts_anns)
os.makedirs(model_name + "/predImages", exist_ok=True) # Make a directory for output images
#random.seed(1)
for d in random.sample(dataset_dicts_anns, num_samples):
  image1 = printImage(d, test_metadata, predictor, True) # Predictions
  image2 = printImage(d, test_metadata, False) # Ground truth
  image3 = hconcat([image1, image2])
  #cv2_imshow(image3)
  cv2.imwrite(model_name + '/predImages/' + str(d["image_id"] + '.jpg'), image3)
